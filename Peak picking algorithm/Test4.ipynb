# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks, savgol_filter

# Directory containing the CSV files
input_directory = r'C:\Users\kulma\OneDrive\Documents\School\MASc Year 1\Surface Profilometry Analyzer\Surface-Profilometry-Analyzer\Peak picking algorithm\path_to_your_output_folder'

# Directory to save the output files
output_directory = os.path.join(input_directory, "Final")

# Create the output directory if it does not exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Function to perform moving average baseline correction
def baseline_correction(data, window_size, max_sweeps):
    corrected = data.copy()
    for _ in range(max_sweeps):
        baseline = pd.Series(corrected).rolling(window=window_size, min_periods=1, center=True).mean()
        corrected = data - baseline
        if np.all(np.isclose(corrected, 0, atol=1e-8)):
            break
    return corrected

# Function to find the lowest value among the local negative peaks (troughs)
def find_lowest_trough_value(data, smooth_window=51, polyorder=3, prominence=0.001):
    # Smooth the data to reduce noise
    smoothed_data = savgol_filter(data, window_length=smooth_window, polyorder=polyorder)
    
    # Invert the data to find negative peaks
    inverted_data = -smoothed_data
    peaks, properties = find_peaks(inverted_data, prominence=prominence)
    
    if len(peaks) == 0:
        return None
    trough_values = data[peaks]
    lowest_trough_value = np.min(trough_values)
    return lowest_trough_value, peaks, smoothed_data

# Process each CSV file in the directory
for filename in os.listdir(input_directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_directory, filename)
        
        # Load data from CSV file
        data = pd.read_csv(file_path)

        # Assuming the relevant data is in the first column
        # Converting the first column to numeric, forcing errors to NaN
        data_values = pd.to_numeric(data.iloc[:, 0], errors='coerce').dropna().values

        if data_values.size == 0:
            print(f"No valid numeric data in {filename}")
            continue

        # Plot the original data
        plt.figure(figsize=(14, 7))
        plt.plot(data_values, label='Original Data')
        plt.title(f'Original Data - {filename}')
        plt.xlabel('Index')
        plt.ylabel('Value')
        plt.legend()
        plt.savefig(os.path.join(output_directory, f"{filename}_original.png"))
        plt.close()

        # Apply baseline correction
        corrected_data = baseline_correction(data_values, window_size=2, max_sweeps=1001)

        # Find the lowest value among the local negative peaks (troughs)
        result = find_lowest_trough_value(corrected_data)
        
        if result is not None:
            lowest_trough_value, troughs, smoothed_data = result
            
            # Plot the corrected data with troughs marked
            plt.figure(figsize=(14, 7))
            plt.plot(corrected_data, label='Corrected Data')
            plt.plot(troughs, corrected_data[troughs], "x", label='Troughs')
            plt.plot(smoothed_data, label='Smoothed Data', linestyle='--')
            plt.title(f'Corrected Data with Troughs - {filename}')
            plt.xlabel('Index')
            plt.ylabel('Value')
            plt.legend()
            plt.savefig(os.path.join(output_directory, f"{filename}_corrected_with_troughs.png"))
            plt.close()

            # Print the lowest trough value
            print(f"Lowest trough value in {filename}: {lowest_trough_value}")
        else:
            print(f"No troughs found in {filename}")
# Out:
# Lowest trough value in 100mV 100Hz_uA.csv: -0.003984774518114011
# Lowest trough value in 100mV 100Hz_µA1.csv: -0.003984774518114011
# Lowest trough value in 100mV 100Hz_µA2.csv: -0.04234210942702074
# Lowest trough value in 100mV 100Hz_µA3.csv: -0.012720408336429623
# Lowest trough value in 100mV 100Hz_µA4.csv: -0.0009634749825361928
# Lowest trough value in 100mV 100Hz_µA5.csv: -0.008085323124043465
# Lowest trough value in 100mV 100Hz_µA6.csv: -0.024989265182252113
# Lowest trough value in 100mV 100Hz_µA7.csv: 0.00030325260604489943
# Lowest trough value in 100mV 100Hz_µA8.csv: -0.030736607507972177
# Lowest trough value in 100mV 150Hz_uA.csv: -0.01493234000156413
# Lowest trough value in 100mV 150Hz_µA1.csv: -0.01493234000156413
# Lowest trough value in 100mV 150Hz_µA2.csv: -0.05961470823923865
# Lowest trough value in 100mV 150Hz_µA3.csv: -0.020407637695631246
# Lowest trough value in 100mV 150Hz_µA4.csv: -0.007167846508965261
# Lowest trough value in 100mV 150Hz_µA5.csv: -0.0017084354806225265
# Lowest trough value in 100mV 150Hz_µA6.csv: -0.05424563739783987
# Lowest trough value in 100mV 150Hz_µA7.csv: -0.005177386201728344
# Lowest trough value in 100mV 150Hz_µA8.csv: -0.03362209482019267
# Lowest trough value in 100mV 200Hz_uA.csv: -0.009769802846344995
# Lowest trough value in 100mV 200Hz_µA1.csv: -0.009769802846344995
# Lowest trough value in 100mV 200Hz_µA2.csv: -0.06897820814737561
# Lowest trough value in 100mV 200Hz_µA3.csv: -0.04788577339854133
# Lowest trough value in 100mV 200Hz_µA4.csv: -0.004906428572729084
# Lowest trough value in 100mV 200Hz_µA5.csv: -0.030149201507809698
# Lowest trough value in 100mV 200Hz_µA6.csv: -0.07940230118971782
# Lowest trough value in 100mV 200Hz_µA7.csv: -0.010982766626508437
# Lowest trough value in 100mV 200Hz_µA8.csv: -0.06087073330654416
# Lowest trough value in 100mV 20Hz_uA.csv: -0.4374300168452415
# Lowest trough value in 100mV 20Hz_µA1.csv: -0.4374300168452415
# No troughs found in 100mV 20Hz_µA2.csv
# Lowest trough value in 100mV 20Hz_µA3.csv: -0.0005972438883163587
# No troughs found in 100mV 20Hz_µA4.csv
# No troughs found in 100mV 20Hz_µA5.csv
# No troughs found in 100mV 20Hz_µA6.csv
# Lowest trough value in 100mV 20Hz_µA7.csv: -0.1834533633284467
# No troughs found in 100mV 20Hz_µA8.csv
# Lowest trough value in 100mV 300Hz_uA.csv: -0.04700505861192331
# Lowest trough value in 100mV 300Hz_µA1.csv: -0.04700505861192331
# Lowest trough value in 100mV 300Hz_µA2.csv: -0.13696356737213491
# Lowest trough value in 100mV 300Hz_µA3.csv: -0.07069350486752711
# Lowest trough value in 100mV 300Hz_µA4.csv: -0.017283055945278916
# Lowest trough value in 100mV 300Hz_µA5.csv: -0.04617152898645045
# Lowest trough value in 100mV 300Hz_µA6.csv: -0.18552074739164978
# Lowest trough value in 100mV 300Hz_µA7.csv: -0.02197230363632938
# Lowest trough value in 100mV 300Hz_µA8.csv: -0.1126355259265126
# Lowest trough value in 100mV 40Hz_uA.csv: -0.3017734780707289
# Lowest trough value in 100mV 40Hz_µA1.csv: -0.3017734780707289
# Lowest trough value in 100mV 40Hz_µA2.csv: -0.007419098382439208
# Lowest trough value in 100mV 40Hz_µA3.csv: -0.0031890958785991373
# No troughs found in 100mV 40Hz_µA4.csv
# No troughs found in 100mV 40Hz_µA5.csv
# Lowest trough value in 100mV 40Hz_µA6.csv: -0.0023186066871682173
# Lowest trough value in 100mV 40Hz_µA7.csv: -0.021805154159063832
# Lowest trough value in 100mV 40Hz_µA8.csv: -0.0037000212105836538
# Lowest trough value in 100mV 60Hz_uA.csv: -0.5361695466880128
# Lowest trough value in 100mV 60Hz_µA1.csv: -0.5361695466880128
# Lowest trough value in 100mV 60Hz_µA2.csv: -0.019812796703776763
# Lowest trough value in 100mV 60Hz_µA3.csv: -0.008748379226208759
# Lowest trough value in 100mV 60Hz_µA4.csv: -0.0017490649419133752
# Lowest trough value in 100mV 60Hz_µA5.csv: -0.0046916156916613425
# Lowest trough value in 100mV 60Hz_µA6.csv: -0.0137121951076394
# Lowest trough value in 100mV 60Hz_µA7.csv: -0.00679951898039481
# Lowest trough value in 100mV 60Hz_µA8.csv: -0.014410305826831709
# Lowest trough value in 100mV 80Hz_uA.csv: -0.003716179706145251
# Lowest trough value in 100mV 80Hz_µA1.csv: -0.003716179706145251
# Lowest trough value in 100mV 80Hz_µA2.csv: -0.03237170229317041
# Lowest trough value in 100mV 80Hz_µA3.csv: -0.008438218597274633
# Lowest trough value in 100mV 80Hz_µA4.csv: 0.0003246203029616682
# Lowest trough value in 100mV 80Hz_µA5.csv: -0.004622300223430253
# Lowest trough value in 100mV 80Hz_µA6.csv: -0.020747125761555983
# Lowest trough value in 100mV 80Hz_µA7.csv: -0.10314911020698322
# Lowest trough value in 100mV 80Hz_µA8.csv: -0.03344025835990862
# Lowest trough value in 20mV 100Hz_uA.csv: -0.008271449233039317
# Lowest trough value in 20mV 100Hz_µA1.csv: -0.008271449233039317
# Lowest trough value in 20mV 100Hz_µA2.csv: -0.05930025133668514
# Lowest trough value in 20mV 100Hz_µA3.csv: -0.037626768529731125
# Lowest trough value in 20mV 100Hz_µA4.csv: -0.012815480402816066
# Lowest trough value in 20mV 100Hz_µA5.csv: -0.01476470773703431
# Lowest trough value in 20mV 100Hz_µA6.csv: -0.06841871104732983
# Lowest trough value in 20mV 100Hz_µA7.csv: -0.03783657460647462
# Lowest trough value in 20mV 100Hz_µA8.csv: -0.04192995589564561
# Lowest trough value in 20mV 150Hz_uA.csv: -0.018055741114985965
# Lowest trough value in 20mV 150Hz_µA1.csv: -0.018055741114985965
# Lowest trough value in 20mV 150Hz_µA2.csv: -0.07867717823364093
# Lowest trough value in 20mV 150Hz_µA3.csv: -0.04693099885537182
# Lowest trough value in 20mV 150Hz_µA4.csv: -0.018877003445548178
# Lowest trough value in 20mV 150Hz_µA5.csv: -0.01453463424497126
# Lowest trough value in 20mV 150Hz_µA6.csv: -0.08640348522155493
# Lowest trough value in 20mV 150Hz_µA7.csv: -0.044809016740360155
# Lowest trough value in 20mV 150Hz_µA8.csv: -0.04766014390182915
# Lowest trough value in 20mV 200Hz_uA.csv: -0.10148752840538394
# Lowest trough value in 20mV 200Hz_µA1.csv: -0.10148752840538394
# Lowest trough value in 20mV 200Hz_µA2.csv: -0.07827101070461469
# Lowest trough value in 20mV 200Hz_µA3.csv: -0.04642236198922253
# Lowest trough value in 20mV 200Hz_µA4.csv: -0.009894424760224903
# Lowest trough value in 20mV 200Hz_µA5.csv: -0.005580584973294465
# Lowest trough value in 20mV 200Hz_µA6.csv: -0.01035640903714892
# Lowest trough value in 20mV 200Hz_µA7.csv: -0.04686529216888101
# Lowest trough value in 20mV 200Hz_µA8.csv: -0.05035090666329378
# Lowest trough value in 20mV 20Hz_uA.csv: -0.008542358533585363
# Lowest trough value in 20mV 20Hz_µA1.csv: -0.008542358533585363
# Lowest trough value in 20mV 20Hz_µA2.csv: -0.005223553208960263
# Lowest trough value in 20mV 20Hz_µA3.csv: -0.0030491142675666385
# Lowest trough value in 20mV 20Hz_µA4.csv: -0.0016492784411760663
# Lowest trough value in 20mV 20Hz_µA5.csv: -0.0022850561620676125
# Lowest trough value in 20mV 20Hz_µA6.csv: -0.015558739045313508
# Lowest trough value in 20mV 20Hz_µA7.csv: -0.007168178549858677
# Lowest trough value in 20mV 20Hz_µA8.csv: -0.008530633642246306
# Lowest trough value in 20mV 300Hz_uA.csv: -0.07169294654658424
# Lowest trough value in 20mV 300Hz_µA1.csv: -0.07169294654658424
# Lowest trough value in 20mV 300Hz_µA2.csv: -0.09421508676283764
# Lowest trough value in 20mV 300Hz_µA3.csv: -0.06482416645191261
# Lowest trough value in 20mV 300Hz_µA4.csv: -0.03156767866372109
# Lowest trough value in 20mV 300Hz_µA5.csv: -0.004374768434201155
# Lowest trough value in 20mV 300Hz_µA6.csv: -0.026527507802129154
# Lowest trough value in 20mV 300Hz_µA7.csv: -0.11509126574852965
# Lowest trough value in 20mV 300Hz_µA8.csv: -0.04602140676168355
# Lowest trough value in 20mV 40Hz_uA.csv: -0.02827438798681533
# Lowest trough value in 20mV 40Hz_µA1.csv: -0.02827438798681533
# Lowest trough value in 20mV 40Hz_µA2.csv: -0.015695863232767362
# Lowest trough value in 20mV 40Hz_µA3.csv: -0.007982332108820291
# Lowest trough value in 20mV 40Hz_µA4.csv: -0.004221894026161997
# Lowest trough value in 20mV 40Hz_µA5.csv: -0.0028291378277278886
# Lowest trough value in 20mV 40Hz_µA6.csv: -0.02905726241426288
# Lowest trough value in 20mV 40Hz_µA7.csv: -0.01945189584119946
# No troughs found in 20mV 40Hz_µA8.csv
# Lowest trough value in 20mV 60Hz_uA.csv: -0.023296334863378662
# Lowest trough value in 20mV 60Hz_µA1.csv: -0.023296334863378662
# Lowest trough value in 20mV 60Hz_µA2.csv: -0.041292243749742774
# Lowest trough value in 20mV 60Hz_µA3.csv: -0.00944403944924848
# Lowest trough value in 20mV 60Hz_µA4.csv: -0.004039131567302555
# Lowest trough value in 20mV 60Hz_µA5.csv: -0.0119008403420011
# Lowest trough value in 20mV 60Hz_µA6.csv: -0.055157688283366785
# Lowest trough value in 20mV 60Hz_µA7.csv: -0.02500603697809593
# Lowest trough value in 20mV 60Hz_µA8.csv: -0.029570627342031995
# Lowest trough value in 20mV 80Hz_uA.csv: -0.005468890735750558
# Lowest trough value in 20mV 80Hz_µA1.csv: -0.005468890735750558
# Lowest trough value in 20mV 80Hz_µA2.csv: -0.05263981104610417
# Lowest trough value in 20mV 80Hz_µA3.csv: -0.03124842267407854
# Lowest trough value in 20mV 80Hz_µA4.csv: -0.008097246044108938
# Lowest trough value in 20mV 80Hz_µA5.csv: -0.012300763201090532
# Lowest trough value in 20mV 80Hz_µA6.csv: -0.06233389497651157
# Lowest trough value in 20mV 80Hz_µA7.csv: -0.033033799402834685
# Lowest trough value in 20mV 80Hz_µA8.csv: -0.037663247013364834
# Lowest trough value in 30mV 100Hz_uA.csv: -0.07697323879696452
# Lowest trough value in 30mV 100Hz_µA1.csv: -0.07697323879696452
# Lowest trough value in 30mV 100Hz_µA2.csv: -0.051678003629598755
# Lowest trough value in 30mV 100Hz_µA3.csv: -0.02112953309201001
# Lowest trough value in 30mV 100Hz_µA4.csv: -0.0071815383204609905
# Lowest trough value in 30mV 100Hz_µA5.csv: -0.016687170207341284
# Lowest trough value in 30mV 100Hz_µA6.csv: -0.06448577343326989
# Lowest trough value in 30mV 100Hz_µA7.csv: -0.0301471477803454
# Lowest trough value in 30mV 100Hz_µA8.csv: -0.05023625066163351
# Lowest trough value in 30mV 150Hz_uA.csv: -0.1041548274744451
# Lowest trough value in 30mV 150Hz_µA1.csv: -0.1041548274744451
# Lowest trough value in 30mV 150Hz_µA2.csv: -0.06738708870585691
# Lowest trough value in 30mV 150Hz_µA3.csv: -0.028059079786686966
# Lowest trough value in 30mV 150Hz_µA4.csv: -0.006722383996263848
# Lowest trough value in 30mV 150Hz_µA5.csv: -0.017517625540718302
# Lowest trough value in 30mV 150Hz_µA6.csv: -0.0769609058609059
# Lowest trough value in 30mV 150Hz_µA7.csv: -0.03810298780307096
# Lowest trough value in 30mV 150Hz_µA8.csv: -0.05653320886371459
# Lowest trough value in 30mV 200Hz_uA.csv: -0.11212353141769121
# Lowest trough value in 30mV 200Hz_µA1.csv: -0.11212353141769121
# Lowest trough value in 30mV 200Hz_µA2.csv: -0.06851798456709657
# Lowest trough value in 30mV 200Hz_µA3.csv: -0.03214546857380814
# Lowest trough value in 30mV 200Hz_µA4.csv: -0.013592436417607066
# Lowest trough value in 30mV 200Hz_µA5.csv: -0.024963545430478462
# Lowest trough value in 30mV 200Hz_µA6.csv: -0.08200743088507345
# Lowest trough value in 30mV 200Hz_µA7.csv: -0.03618080446733209
# Lowest trough value in 30mV 200Hz_µA8.csv: -0.06793507493982973
# No troughs found in 30mV 20Hz_uA.csv
# No troughs found in 30mV 20Hz_µA1.csv
# Lowest trough value in 30mV 20Hz_µA2.csv: -0.004286959636811279
# Lowest trough value in 30mV 20Hz_µA3.csv: -0.0042905751865063915
# Lowest trough value in 30mV 20Hz_µA4.csv: -0.003116009879286118
# Lowest trough value in 30mV 20Hz_µA5.csv: -0.08539790842293105
# No troughs found in 30mV 20Hz_µA6.csv
# Lowest trough value in 30mV 20Hz_µA7.csv: -0.1613937029202771
# Lowest trough value in 30mV 20Hz_µA8.csv: -0.03617668532096424
# Lowest trough value in 30mV 300Hz_uA.csv: -0.11813940163804143
# Lowest trough value in 30mV 300Hz_µA1.csv: -0.11813940163804143
# Lowest trough value in 30mV 300Hz_µA2.csv: -0.09209130884153871
# Lowest trough value in 30mV 300Hz_µA3.csv: -0.02183442225533424
# Lowest trough value in 30mV 300Hz_µA4.csv: -0.017239960790397454
# Lowest trough value in 30mV 300Hz_µA5.csv: -0.03769430153677748
# Lowest trough value in 30mV 300Hz_µA6.csv: -0.08662139006123588
# Lowest trough value in 30mV 300Hz_µA7.csv: -0.054046074513613755
# Lowest trough value in 30mV 300Hz_µA8.csv: -0.08179910387032288
# Lowest trough value in 30mV 40Hz_uA.csv: -0.014219058616790781
# Lowest trough value in 30mV 40Hz_µA1.csv: -0.014219058616790781
# Lowest trough value in 30mV 40Hz_µA2.csv: -0.018671874473556577
# Lowest trough value in 30mV 40Hz_µA3.csv: -0.007942991411771357
# No troughs found in 30mV 40Hz_µA4.csv
# No troughs found in 30mV 40Hz_µA5.csv
# Lowest trough value in 30mV 40Hz_µA6.csv: -0.12580202297540416
# No troughs found in 30mV 40Hz_µA7.csv
# No troughs found in 30mV 40Hz_µA8.csv
# Lowest trough value in 30mV 60Hz_uA.csv: -0.048480670185897023
# Lowest trough value in 30mV 60Hz_µA1.csv: -0.048480670185897023
# Lowest trough value in 30mV 60Hz_µA2.csv: -0.03138836669933244
# Lowest trough value in 30mV 60Hz_µA3.csv: -0.013693661398869648
# Lowest trough value in 30mV 60Hz_µA4.csv: -0.0022444738399784647
# Lowest trough value in 30mV 60Hz_µA5.csv: -0.013590123572077752
# Lowest trough value in 30mV 60Hz_µA6.csv: -0.06313440182915417
# Lowest trough value in 30mV 60Hz_µA7.csv: -0.022351443568745855
# Lowest trough value in 30mV 60Hz_µA8.csv: -0.030419968561953517
# Lowest trough value in 30mV 80Hz_uA.csv: -0.06510145339985347
# Lowest trough value in 30mV 80Hz_µA1.csv: -0.06510145339985347
# Lowest trough value in 30mV 80Hz_µA2.csv: -0.041445903851841034
# Lowest trough value in 30mV 80Hz_µA3.csv: -0.015729942589343054
# Lowest trough value in 30mV 80Hz_µA4.csv: -0.0018952162071859142
# Lowest trough value in 30mV 80Hz_µA5.csv: -0.018988108995656783
# Lowest trough value in 30mV 80Hz_µA6.csv: -0.05352136450684854
# Lowest trough value in 30mV 80Hz_µA7.csv: -0.028941769223631092
# Lowest trough value in 30mV 80Hz_µA8.csv: -0.03911553826115899
# Lowest trough value in 40mV 100Hz_uA.csv: -0.027367210789790687
# Lowest trough value in 40mV 100Hz_µA1.csv: -0.027367210789790687
# Lowest trough value in 40mV 100Hz_µA2.csv: -0.06374936738850753
# Lowest trough value in 40mV 100Hz_µA3.csv: -0.024129055338812246
# Lowest trough value in 40mV 100Hz_µA4.csv: -0.007390710298121748
# Lowest trough value in 40mV 100Hz_µA5.csv: -0.025720176703261953
# Lowest trough value in 40mV 100Hz_µA6.csv: -0.06130482426602106
# Lowest trough value in 40mV 100Hz_µA7.csv: -0.23253951526529182
# Lowest trough value in 40mV 100Hz_µA8.csv: -0.042292431118348475
# Lowest trough value in 40mV 10Hz_uA.csv: -0.3221550396525621
# Lowest trough value in 40mV 10Hz_µA1.csv: -0.3221550396525621
# No troughs found in 40mV 10Hz_µA2.csv
# No troughs found in 40mV 10Hz_µA3.csv
# No troughs found in 40mV 10Hz_µA4.csv
# No troughs found in 40mV 10Hz_µA5.csv
# Lowest trough value in 40mV 10Hz_µA6.csv: -0.14062610557276822
# Lowest trough value in 40mV 10Hz_µA7.csv: -0.25506105589045125
# No troughs found in 40mV 10Hz_µA8.csv
# Lowest trough value in 40mV 150Hz_uA.csv: -0.052121150156676954
# Lowest trough value in 40mV 150Hz_µA1.csv: -0.052121150156676954
# Lowest trough value in 40mV 150Hz_µA2.csv: -0.08702088577912678
# Lowest trough value in 40mV 150Hz_µA3.csv: -0.03219992839329809
# Lowest trough value in 40mV 150Hz_µA4.csv: -0.008691422273938133
# Lowest trough value in 40mV 150Hz_µA5.csv: -0.027342409859446547
# Lowest trough value in 40mV 150Hz_µA6.csv: -0.0839461304480932
# Lowest trough value in 40mV 150Hz_µA7.csv: -0.04409983666885736
# Lowest trough value in 40mV 150Hz_µA8.csv: -0.06348530373563813
# Lowest trough value in 40mV 200Hz_uA.csv: -0.06646586420069572
# Lowest trough value in 40mV 200Hz_µA1.csv: -0.06646586420069572
# Lowest trough value in 40mV 200Hz_µA2.csv: -0.08968309727942664
# Lowest trough value in 40mV 200Hz_µA3.csv: -0.026902982339536897
# Lowest trough value in 40mV 200Hz_µA4.csv: -0.013972561184934285
# Lowest trough value in 40mV 200Hz_µA5.csv: -0.023739202221537595
# Lowest trough value in 40mV 200Hz_µA6.csv: -0.10957948989310874
# Lowest trough value in 40mV 200Hz_µA7.csv: -0.03111402113937023
# Lowest trough value in 40mV 200Hz_µA8.csv: -0.06640880773258552
# Lowest trough value in 40mV 20Hz_uA.csv: -0.4185480851056073
# Lowest trough value in 40mV 20Hz_µA1.csv: -0.4185480851056073
# Lowest trough value in 40mV 20Hz_µA2.csv: -0.0027647148277261486
# Lowest trough value in 40mV 20Hz_µA3.csv: -0.001330700110167224
# No troughs found in 40mV 20Hz_µA4.csv
# No troughs found in 40mV 20Hz_µA5.csv
# Lowest trough value in 40mV 20Hz_µA6.csv: -0.12456794370410387
# Lowest trough value in 40mV 20Hz_µA7.csv: -0.26052266770095334
# No troughs found in 40mV 20Hz_µA8.csv
# Lowest trough value in 40mV 300Hz_uA.csv: -0.07054475603831514
# Lowest trough value in 40mV 300Hz_µA1.csv: -0.07054475603831514
# Lowest trough value in 40mV 300Hz_µA2.csv: -0.12731387931147564
# Lowest trough value in 40mV 300Hz_µA3.csv: -0.03866909316743922
# Lowest trough value in 40mV 300Hz_µA4.csv: -0.018423715302244757
# Lowest trough value in 40mV 300Hz_µA5.csv: -0.046556179589911886
# Lowest trough value in 40mV 300Hz_µA6.csv: -0.10431326653173073
# Lowest trough value in 40mV 300Hz_µA7.csv: -0.024382370412228016
# Lowest trough value in 40mV 300Hz_µA8.csv: -0.0938152389694764
# Lowest trough value in 40mV 40Hz_uA.csv: -0.16049713095372686
# Lowest trough value in 40mV 40Hz_µA1.csv: -0.16049713095372686
# Lowest trough value in 40mV 40Hz_µA2.csv: -0.016522244094054037
# Lowest trough value in 40mV 40Hz_µA3.csv: -0.008904010231997595
# No troughs found in 40mV 40Hz_µA4.csv
# No troughs found in 40mV 40Hz_µA5.csv
# No troughs found in 40mV 40Hz_µA6.csv
# Lowest trough value in 40mV 40Hz_µA7.csv: -0.26614590994358156
# No troughs found in 40mV 40Hz_µA8.csv
# Lowest trough value in 40mV 60Hz_uA.csv: -0.026498965875244043
# Lowest trough value in 40mV 60Hz_µA1.csv: -0.026498965875244043
# Lowest trough value in 40mV 60Hz_µA2.csv: -0.03289523181136538
# Lowest trough value in 40mV 60Hz_µA3.csv: -0.015390397058302054
# Lowest trough value in 40mV 60Hz_µA4.csv: 1.681144825067338e-05
# Lowest trough value in 40mV 60Hz_µA5.csv: -0.01288847183659328
# Lowest trough value in 40mV 60Hz_µA6.csv: -0.03234200867618825
# Lowest trough value in 40mV 60Hz_µA7.csv: -0.28826801034978955
# Lowest trough value in 40mV 60Hz_µA8.csv: -0.02483344009971683
# Lowest trough value in 40mV 80Hz_uA.csv: -0.024937043063471658
# Lowest trough value in 40mV 80Hz_µA1.csv: -0.024937043063471658
# Lowest trough value in 40mV 80Hz_µA2.csv: -0.04770219194592555
# Lowest trough value in 40mV 80Hz_µA3.csv: -0.01999497599582065
# Lowest trough value in 40mV 80Hz_µA4.csv: -0.0044343874329514634
# Lowest trough value in 40mV 80Hz_µA5.csv: -0.022116577156647034
# Lowest trough value in 40mV 80Hz_µA6.csv: -0.04493134030071627
# Lowest trough value in 40mV 80Hz_µA7.csv: -0.28632672444396895
# Lowest trough value in 40mV 80Hz_µA8.csv: -0.03173677687016366
# Lowest trough value in 50mV 100Hz_uA.csv: -0.026948333237762148
# Lowest trough value in 50mV 100Hz_µA1.csv: -0.026948333237762148
# Lowest trough value in 50mV 100Hz_µA2.csv: -0.06046692898174008
# Lowest trough value in 50mV 100Hz_µA3.csv: -0.029063740856402467
# Lowest trough value in 50mV 100Hz_µA4.csv: -0.004223506186355216
# Lowest trough value in 50mV 100Hz_µA5.csv: -0.024102717194695554
# Lowest trough value in 50mV 100Hz_µA6.csv: -0.06645144382034618
# Lowest trough value in 50mV 100Hz_µA7.csv: -0.060992412978503247
# Lowest trough value in 50mV 100Hz_µA8.csv: -0.03558948437381281
# Lowest trough value in 50mV 150Hz_uA.csv: -0.0409363106159128
# Lowest trough value in 50mV 150Hz_µA1.csv: -0.0409363106159128
# Lowest trough value in 50mV 150Hz_µA2.csv: -0.09340068423381104
# Lowest trough value in 50mV 150Hz_µA3.csv: -0.03190180603237983
# Lowest trough value in 50mV 150Hz_µA4.csv: -0.014911368087313526
# Lowest trough value in 50mV 150Hz_µA5.csv: -0.03443045481518211
# Lowest trough value in 50mV 150Hz_µA6.csv: -0.09692159334987521
# Lowest trough value in 50mV 150Hz_µA7.csv: -0.01080627166022042
# Lowest trough value in 50mV 150Hz_µA8.csv: -0.05646044915252352
# Lowest trough value in 50mV 200Hz_uA.csv: -0.06474359568002483
# Lowest trough value in 50mV 200Hz_µA1.csv: -0.06474359568002483
# Lowest trough value in 50mV 200Hz_µA2.csv: -0.11627623163264891
# Lowest trough value in 50mV 200Hz_µA3.csv: -0.039983502758838704
# Lowest trough value in 50mV 200Hz_µA4.csv: -0.006222252674015601
# Lowest trough value in 50mV 200Hz_µA5.csv: -0.04323197095037765
# Lowest trough value in 50mV 200Hz_µA6.csv: -0.1293469884328286
# Lowest trough value in 50mV 200Hz_µA7.csv: -0.027839900933022382
# Lowest trough value in 50mV 200Hz_µA8.csv: -0.060910996196772774
# Lowest trough value in 50mV 20Hz_uA.csv: -0.3254574287585219
# Lowest trough value in 50mV 20Hz_µA1.csv: -0.3254574287585219
# Lowest trough value in 50mV 20Hz_µA2.csv: -0.0027565287154872526
# No troughs found in 50mV 20Hz_µA3.csv
# No troughs found in 50mV 20Hz_µA4.csv
# No troughs found in 50mV 20Hz_µA5.csv
# No troughs found in 50mV 20Hz_µA6.csv
# Lowest trough value in 50mV 20Hz_µA7.csv: -0.23711981249696656
# No troughs found in 50mV 20Hz_µA8.csv
# Lowest trough value in 50mV 300Hz_uA.csv: -0.061779800396447926
# Lowest trough value in 50mV 300Hz_µA1.csv: -0.061779800396447926
# Lowest trough value in 50mV 300Hz_µA2.csv: -0.15875085865764185
# Lowest trough value in 50mV 300Hz_µA3.csv: -0.08040426432740624
# Lowest trough value in 50mV 300Hz_µA4.csv: -0.01702633433940813
# Lowest trough value in 50mV 300Hz_µA5.csv: -0.048415263818667495
# Lowest trough value in 50mV 300Hz_µA6.csv: -0.1581702313575541
# Lowest trough value in 50mV 300Hz_µA7.csv: -0.0329320431916125
# Lowest trough value in 50mV 300Hz_µA8.csv: -0.10443725624774979
# Lowest trough value in 50mV 40Hz_uA.csv: -0.23787943624838695
# Lowest trough value in 50mV 40Hz_µA1.csv: -0.23787943624838695
# Lowest trough value in 50mV 40Hz_µA2.csv: -0.010868428421215059
# Lowest trough value in 50mV 40Hz_µA3.csv: -0.006456561497931907
# No troughs found in 50mV 40Hz_µA4.csv
# No troughs found in 50mV 40Hz_µA5.csv
# No troughs found in 50mV 40Hz_µA6.csv
# Lowest trough value in 50mV 40Hz_µA7.csv: -0.2507555845780577
# No troughs found in 50mV 40Hz_µA8.csv
# Lowest trough value in 50mV 60Hz_uA.csv: -0.041383072348815095
# Lowest trough value in 50mV 60Hz_µA1.csv: -0.041383072348815095
# Lowest trough value in 50mV 60Hz_µA2.csv: -0.026727024770232834
# Lowest trough value in 50mV 60Hz_µA3.csv: -0.014252006860561595
# Lowest trough value in 50mV 60Hz_µA4.csv: -0.0024604807624025032
# Lowest trough value in 50mV 60Hz_µA5.csv: -0.01156376096280005
# Lowest trough value in 50mV 60Hz_µA6.csv: -0.03128693006694322
# Lowest trough value in 50mV 60Hz_µA7.csv: -0.21228762459196365
# Lowest trough value in 50mV 60Hz_µA8.csv: -0.017691427882090154
# Lowest trough value in 50mV 80Hz_uA.csv: -0.018421846972015953
# Lowest trough value in 50mV 80Hz_µA1.csv: -0.018421846972015953
# Lowest trough value in 50mV 80Hz_µA2.csv: -0.043887870459108004
# Lowest trough value in 50mV 80Hz_µA3.csv: -0.02110595613324199
# Lowest trough value in 50mV 80Hz_µA4.csv: -0.0017724640281193771
# Lowest trough value in 50mV 80Hz_µA5.csv: -0.01733767318098333
# Lowest trough value in 50mV 80Hz_µA6.csv: -0.050682488376488595
# Lowest trough value in 50mV 80Hz_µA7.csv: -0.1020525778697512
# Lowest trough value in 50mV 80Hz_µA8.csv: -0.029710042680342393
# Lowest trough value in 60mV 100Hz_uA.csv: -0.020296279997744672
# Lowest trough value in 60mV 100Hz_µA1.csv: -0.020296279997744672
# Lowest trough value in 60mV 100Hz_µA2.csv: -0.04702054040599024
# Lowest trough value in 60mV 100Hz_µA3.csv: -0.02195267746183511
# Lowest trough value in 60mV 100Hz_µA4.csv: -0.003254067303505507
# Lowest trough value in 60mV 100Hz_µA5.csv: -0.021801188431420995
# Lowest trough value in 60mV 100Hz_µA6.csv: -0.06890524902922807
# Lowest trough value in 60mV 100Hz_µA7.csv: -0.13171972415232752
# Lowest trough value in 60mV 100Hz_µA8.csv: -0.03461960500635676
# Lowest trough value in 60mV 150Hz_uA.csv: -0.03593739338129971
# Lowest trough value in 60mV 150Hz_µA1.csv: -0.03593739338129971
# Lowest trough value in 60mV 150Hz_µA2.csv: -0.09588788583265467
# Lowest trough value in 60mV 150Hz_µA3.csv: -0.04403734955909749
# Lowest trough value in 60mV 150Hz_µA4.csv: -0.0046023745527521386
# Lowest trough value in 60mV 150Hz_µA5.csv: -0.03621850868056254
# Lowest trough value in 60mV 150Hz_µA6.csv: -0.1072361973517091
# Lowest trough value in 60mV 150Hz_µA7.csv: -0.1552288540763282
# Lowest trough value in 60mV 150Hz_µA8.csv: -0.053282827655063106
# Lowest trough value in 60mV 200Hz_uA.csv: -0.05286221726534697
# Lowest trough value in 60mV 200Hz_µA1.csv: -0.05286221726534697
# Lowest trough value in 60mV 200Hz_µA2.csv: -0.13127878256710296
# Lowest trough value in 60mV 200Hz_µA3.csv: -0.036600007738468554
# Lowest trough value in 60mV 200Hz_µA4.csv: -0.016773864849115312
# Lowest trough value in 60mV 200Hz_µA5.csv: -0.053425435019674256
# Lowest trough value in 60mV 200Hz_µA6.csv: -0.13966100007990434
# Lowest trough value in 60mV 200Hz_µA7.csv: -0.011495310689154745
# Lowest trough value in 60mV 200Hz_µA8.csv: -0.08637365457187604
# Lowest trough value in 60mV 300Hz_uA.csv: -0.07919471957799612
# Lowest trough value in 60mV 300Hz_µA1.csv: -0.07919471957799612
# Lowest trough value in 60mV 300Hz_µA2.csv: -0.1915891758568842
# Lowest trough value in 60mV 300Hz_µA3.csv: -0.06263551251819939
# Lowest trough value in 60mV 300Hz_µA4.csv: -0.021847042605255156
# Lowest trough value in 60mV 300Hz_µA5.csv: -0.05102155207114373
# Lowest trough value in 60mV 300Hz_µA6.csv: -0.20354143243365164
# Lowest trough value in 60mV 300Hz_µA7.csv: -0.05118067353507526
# Lowest trough value in 60mV 300Hz_µA8.csv: -0.11641107678440384
# Lowest trough value in 60mV 80Hz_uA.csv: -0.012835501134466257
# Lowest trough value in 60mV 80Hz_µA1.csv: -0.012835501134466257
# Lowest trough value in 60mV 80Hz_µA2.csv: -0.03304964725263033
# Lowest trough value in 60mV 80Hz_µA3.csv: -0.017934888687110344
# Lowest trough value in 60mV 80Hz_µA4.csv: -0.001362267014579849
# Lowest trough value in 60mV 80Hz_µA5.csv: -0.013632415947365716
# Lowest trough value in 60mV 80Hz_µA6.csv: -0.05039025743640456
# Lowest trough value in 60mV 80Hz_µA7.csv: -0.10342123712065557
# Lowest trough value in 60mV 80Hz_µA8.csv: -0.027445406897966648
# Lowest trough value in 70mV 100Hz_uA.csv: -0.009301916555774087
# Lowest trough value in 70mV 100Hz_µA1.csv: -0.009301916555774087
# Lowest trough value in 70mV 100Hz_µA2.csv: -0.03975894856052317
# Lowest trough value in 70mV 100Hz_µA3.csv: -0.023553148923978272
# Lowest trough value in 70mV 100Hz_µA4.csv: -0.0023662288727731157
# Lowest trough value in 70mV 100Hz_µA5.csv: -0.01469159858362178
# Lowest trough value in 70mV 100Hz_µA6.csv: -0.05955310193573121
# Lowest trough value in 70mV 100Hz_µA7.csv: -0.05985217413370195
# Lowest trough value in 70mV 100Hz_µA8.csv: -0.026121658423128392
# Lowest trough value in 70mV 150Hz_uA.csv: -0.026785122744055305
# Lowest trough value in 70mV 150Hz_µA1.csv: -0.026785122744055305
# Lowest trough value in 70mV 150Hz_µA2.csv: -0.07810414468274168
# Lowest trough value in 70mV 150Hz_µA3.csv: -0.03540631230259762
# Lowest trough value in 70mV 150Hz_µA4.csv: -0.007975398139496402
# Lowest trough value in 70mV 150Hz_µA5.csv: -0.02534863674550137
# Lowest trough value in 70mV 150Hz_µA6.csv: -0.1035179589986969
# Lowest trough value in 70mV 150Hz_µA7.csv: -0.339148179302522
# Lowest trough value in 70mV 150Hz_µA8.csv: -0.0609448463892248
# Lowest trough value in 70mV 200Hz_uA.csv: -0.038276739120126996
# Lowest trough value in 70mV 200Hz_µA1.csv: -0.038276739120126996
# Lowest trough value in 70mV 200Hz_µA2.csv: -0.12496983367133888
# Lowest trough value in 70mV 200Hz_µA3.csv: -0.04802531349717361
# Lowest trough value in 70mV 200Hz_µA4.csv: -0.007655102663093669
# Lowest trough value in 70mV 200Hz_µA5.csv: -0.049049264704263906
# Lowest trough value in 70mV 200Hz_µA6.csv: -0.15262247949088176
# Lowest trough value in 70mV 200Hz_µA7.csv: -0.02935350602710507
# Lowest trough value in 70mV 200Hz_µA8.csv: -0.08256648652152007
# Lowest trough value in 70mV 20Hz_uA.csv: -0.5262488311883453
# Lowest trough value in 70mV 20Hz_µA1.csv: -0.5262488311883453
# Lowest trough value in 70mV 20Hz_µA2.csv: -0.0019662181712301044
# Lowest trough value in 70mV 20Hz_µA3.csv: -0.0010108655942786186
# No troughs found in 70mV 20Hz_µA4.csv
# No troughs found in 70mV 20Hz_µA5.csv
# No troughs found in 70mV 20Hz_µA6.csv
# Lowest trough value in 70mV 20Hz_µA7.csv: -0.3832855178838548
# No troughs found in 70mV 20Hz_µA8.csv
# Lowest trough value in 70mV 300Hz_uA.csv: -0.08482733593344201
# Lowest trough value in 70mV 300Hz_µA1.csv: -0.08482733593344201
# Lowest trough value in 70mV 300Hz_µA2.csv: -0.18978340602873817
# Lowest trough value in 70mV 300Hz_µA3.csv: -0.06553054670714498
# Lowest trough value in 70mV 300Hz_µA4.csv: -0.03037876847810911
# Lowest trough value in 70mV 300Hz_µA5.csv: -0.07026385383687264
# Lowest trough value in 70mV 300Hz_µA6.csv: -0.19464845853176516
# Lowest trough value in 70mV 300Hz_µA7.csv: -0.028567742545785552
# Lowest trough value in 70mV 300Hz_µA8.csv: -0.1271139240314842
# Lowest trough value in 70mV 40Hz_uA.csv: -0.2177214440328847
# Lowest trough value in 70mV 40Hz_µA1.csv: -0.2177214440328847
# Lowest trough value in 70mV 40Hz_µA2.csv: -0.007952799260070545
# Lowest trough value in 70mV 40Hz_µA3.csv: -0.004633417060192772
# No troughs found in 70mV 40Hz_µA4.csv
# No troughs found in 70mV 40Hz_µA5.csv
# No troughs found in 70mV 40Hz_µA6.csv
# Lowest trough value in 70mV 40Hz_µA7.csv: -0.09869094323004238
# No troughs found in 70mV 40Hz_µA8.csv
# Lowest trough value in 70mV 60Hz_uA.csv: -0.04650594340551534
# Lowest trough value in 70mV 60Hz_µA1.csv: -0.04650594340551534
# Lowest trough value in 70mV 60Hz_µA2.csv: -0.01656877884696855
# Lowest trough value in 70mV 60Hz_µA3.csv: -0.010229220127907286
# Lowest trough value in 70mV 60Hz_µA4.csv: -0.0007017812901188476
# Lowest trough value in 70mV 60Hz_µA5.csv: -0.00472719059603558
# Lowest trough value in 70mV 60Hz_µA6.csv: -0.020739902045332506
# Lowest trough value in 70mV 60Hz_µA7.csv: -0.2247476032487902
# Lowest trough value in 70mV 60Hz_µA8.csv: -0.010521600287443046
# Lowest trough value in 70mV 80Hz_uA.csv: -0.003944546445656474
# Lowest trough value in 70mV 80Hz_µA1.csv: -0.003944546445656474
# Lowest trough value in 70mV 80Hz_µA2.csv: -0.02614857435145266
# Lowest trough value in 70mV 80Hz_µA3.csv: -0.01611001552294515
# Lowest trough value in 70mV 80Hz_µA4.csv: -0.0029457349950229566
# Lowest trough value in 70mV 80Hz_µA5.csv: -0.009948612489537286
# Lowest trough value in 70mV 80Hz_µA6.csv: -0.03841853353473021
# Lowest trough value in 70mV 80Hz_µA7.csv: -0.1005908220315554
# Lowest trough value in 70mV 80Hz_µA8.csv: -0.019889067737190493
# Lowest trough value in 80mV 100Hz_uA.csv: -0.004315969065755202
# Lowest trough value in 80mV 100Hz_µA1.csv: -0.004315969065755202
# Lowest trough value in 80mV 100Hz_µA2.csv: -0.036169491748411844
# Lowest trough value in 80mV 100Hz_µA3.csv: -0.016512961836608997
# Lowest trough value in 80mV 100Hz_µA4.csv: -0.0022264463475247477
# Lowest trough value in 80mV 100Hz_µA5.csv: -0.00962624829324221
# Lowest trough value in 80mV 100Hz_µA6.csv: -0.03689228014494356
# Lowest trough value in 80mV 100Hz_µA7.csv: -0.15279859048744027
# Lowest trough value in 80mV 100Hz_µA8.csv: -0.014623404612177836
# Lowest trough value in 80mV 150Hz_uA.csv: -0.015791327227312094
# Lowest trough value in 80mV 150Hz_µA1.csv: -0.015791327227312094
# Lowest trough value in 80mV 150Hz_µA2.csv: -0.06104257054223393
# Lowest trough value in 80mV 150Hz_µA3.csv: -0.034751108509887774
# Lowest trough value in 80mV 150Hz_µA4.csv: -0.010292627419758468
# Lowest trough value in 80mV 150Hz_µA5.csv: -0.01641758498112344
# Lowest trough value in 80mV 150Hz_µA6.csv: -0.06757310813480594
# Lowest trough value in 80mV 150Hz_µA7.csv: -0.006887831632002064
# Lowest trough value in 80mV 150Hz_µA8.csv: -0.03453136763405956
# Lowest trough value in 80mV 200Hz_uA.csv: -0.02309597096533669
# Lowest trough value in 80mV 200Hz_µA1.csv: -0.02309597096533669
# Lowest trough value in 80mV 200Hz_µA2.csv: -0.09414558615204119
# Lowest trough value in 80mV 200Hz_µA3.csv: -0.028838243438462037
# Lowest trough value in 80mV 200Hz_µA4.csv: -0.0070504101966077665
# Lowest trough value in 80mV 200Hz_µA5.csv: -0.030941263103785387
# Lowest trough value in 80mV 200Hz_µA6.csv: -0.1233044047387188
# Lowest trough value in 80mV 200Hz_µA7.csv: -0.0701797323922557
# Lowest trough value in 80mV 200Hz_µA8.csv: -0.055254866810240846
# Lowest trough value in 80mV 20Hz_uA.csv: -0.5646902735578037
# Lowest trough value in 80mV 20Hz_µA1.csv: -0.5646902735578037
# Lowest trough value in 80mV 20Hz_µA2.csv: -0.0017488743732846867
# Lowest trough value in 80mV 20Hz_µA3.csv: -0.0010914357736837694
# No troughs found in 80mV 20Hz_µA4.csv
# No troughs found in 80mV 20Hz_µA5.csv
# No troughs found in 80mV 20Hz_µA6.csv
# Lowest trough value in 80mV 20Hz_µA7.csv: -0.35721301759802687
# No troughs found in 80mV 20Hz_µA8.csv
# Lowest trough value in 80mV 300Hz_uA.csv: -0.0524760871926795
# Lowest trough value in 80mV 300Hz_µA1.csv: -0.0524760871926795
# Lowest trough value in 80mV 300Hz_µA2.csv: -0.1837412104036879
# Lowest trough value in 80mV 300Hz_µA3.csv: -0.0694009412288407
# Lowest trough value in 80mV 300Hz_µA4.csv: -0.012554000100630201
# Lowest trough value in 80mV 300Hz_µA5.csv: -0.026150915677056227
# Lowest trough value in 80mV 300Hz_µA6.csv: -0.18105212404132565
# Lowest trough value in 80mV 300Hz_µA7.csv: -0.018815331202829903
# Lowest trough value in 80mV 300Hz_µA8.csv: -0.10515433145006389
# Lowest trough value in 80mV 40Hz_uA.csv: -0.053508862323246406
# Lowest trough value in 80mV 40Hz_µA1.csv: -0.053508862323246406
# Lowest trough value in 80mV 40Hz_µA2.csv: -0.010063663994692783
# Lowest trough value in 80mV 40Hz_µA3.csv: -0.005343098396280967
# No troughs found in 80mV 40Hz_µA4.csv
# Lowest trough value in 80mV 40Hz_µA5.csv: -0.002446650873940306
# Lowest trough value in 80mV 40Hz_µA6.csv: -0.0013731823961936227
# Lowest trough value in 80mV 40Hz_µA7.csv: -0.12464019388640048
# No troughs found in 80mV 40Hz_µA8.csv
# Lowest trough value in 80mV 60Hz_uA.csv: -0.004144297934356656
# Lowest trough value in 80mV 60Hz_µA1.csv: -0.004144297934356656
# Lowest trough value in 80mV 60Hz_µA2.csv: -0.019940174139243247
# Lowest trough value in 80mV 60Hz_µA3.csv: -0.008045797545605693
# Lowest trough value in 80mV 60Hz_µA4.csv: -0.0003954003668680322
# Lowest trough value in 80mV 60Hz_µA5.csv: -0.00541136530193222
# Lowest trough value in 80mV 60Hz_µA6.csv: -0.01684276025255508
# Lowest trough value in 80mV 60Hz_µA7.csv: -0.037768749350956254
# Lowest trough value in 80mV 60Hz_µA8.csv: -0.009939706718982767
# Lowest trough value in 90mV 100Hz_uA.csv: -0.007844772972921582
# Lowest trough value in 90mV 100Hz_µA1.csv: -0.007844772972921582
# Lowest trough value in 90mV 100Hz_µA2.csv: -0.035119353235648645
# Lowest trough value in 90mV 100Hz_µA3.csv: -0.013983380947937264
# Lowest trough value in 90mV 100Hz_µA4.csv: -0.0015343685711005743
# Lowest trough value in 90mV 100Hz_µA5.csv: -0.007251389206684479
# Lowest trough value in 90mV 100Hz_µA6.csv: -0.034350859213869864
# Lowest trough value in 90mV 100Hz_µA7.csv: -0.00309638517532911
# Lowest trough value in 90mV 100Hz_µA8.csv: -0.013797397854939712
# Lowest trough value in 90mV 150Hz_uA.csv: -0.01203895076208681
# Lowest trough value in 90mV 150Hz_µA1.csv: -0.01203895076208681
# Lowest trough value in 90mV 150Hz_µA2.csv: -0.049985835580474106
# Lowest trough value in 90mV 150Hz_µA3.csv: -0.036293535679942035
# Lowest trough value in 90mV 150Hz_µA4.csv: -0.010596768678829496
# Lowest trough value in 90mV 150Hz_µA5.csv: -0.007101904679634473
# Lowest trough value in 90mV 150Hz_µA6.csv: -0.0609851027164619
# Lowest trough value in 90mV 150Hz_µA7.csv: -0.010510664868385235
# Lowest trough value in 90mV 150Hz_µA8.csv: -0.025874927367463774
# Lowest trough value in 90mV 200Hz_uA.csv: -0.02826524034131377
# Lowest trough value in 90mV 200Hz_µA1.csv: -0.02826524034131377
# Lowest trough value in 90mV 200Hz_µA2.csv: -0.061109526598795066
# Lowest trough value in 90mV 200Hz_µA3.csv: -0.040866154654335865
# Lowest trough value in 90mV 200Hz_µA4.csv: -0.018794765182270325
# Lowest trough value in 90mV 200Hz_µA5.csv: -0.013517583637263325
# Lowest trough value in 90mV 200Hz_µA6.csv: -0.10124839332036409
# Lowest trough value in 90mV 200Hz_µA7.csv: -0.01666761364182035
# Lowest trough value in 90mV 200Hz_µA8.csv: -0.05961878824161063
# Lowest trough value in 90mV 20Hz_uA.csv: -0.6002355692316778
# Lowest trough value in 90mV 20Hz_µA1.csv: -0.6002355692316778
# Lowest trough value in 90mV 20Hz_µA2.csv: -0.0015154485792820264
# Lowest trough value in 90mV 20Hz_µA3.csv: -0.0014680985267534006
# No troughs found in 90mV 20Hz_µA4.csv
# No troughs found in 90mV 20Hz_µA5.csv
# No troughs found in 90mV 20Hz_µA6.csv
# Lowest trough value in 90mV 20Hz_µA7.csv: -0.09279622153977905
# No troughs found in 90mV 20Hz_µA8.csv
# Lowest trough value in 90mV 300Hz_uA.csv: -0.04033108435761401
# Lowest trough value in 90mV 300Hz_µA1.csv: -0.04033108435761401
# Lowest trough value in 90mV 300Hz_µA2.csv: -0.15500055885673694
# Lowest trough value in 90mV 300Hz_µA3.csv: -0.07293707378425636
# Lowest trough value in 90mV 300Hz_µA4.csv: -0.024373635556104258
# Lowest trough value in 90mV 300Hz_µA5.csv: -0.043112277191953194
# Lowest trough value in 90mV 300Hz_µA6.csv: -0.21441009523619908
# Lowest trough value in 90mV 300Hz_µA7.csv: -0.012435607221563068
# Lowest trough value in 90mV 300Hz_µA8.csv: -0.0945750931271625
# No troughs found in 90mV 40Hz_uA.csv
# No troughs found in 90mV 40Hz_µA1.csv
# Lowest trough value in 90mV 40Hz_µA2.csv: -0.00940602521712008
# Lowest trough value in 90mV 40Hz_µA3.csv: -0.0031768893291726115
# No troughs found in 90mV 40Hz_µA4.csv
# No troughs found in 90mV 40Hz_µA5.csv
# Lowest trough value in 90mV 40Hz_µA6.csv: -0.0014090116807170764
# Lowest trough value in 90mV 40Hz_µA7.csv: -0.04927437894104303
# Lowest trough value in 90mV 40Hz_µA8.csv: -0.002294483575054873
# Lowest trough value in 90mV 60Hz_uA.csv: -0.0031487142501757936
# Lowest trough value in 90mV 60Hz_µA1.csv: -0.0031487142501757936
# Lowest trough value in 90mV 60Hz_µA2.csv: -0.019852863056154017
# Lowest trough value in 90mV 60Hz_µA3.csv: -0.008509538449385026
# Lowest trough value in 90mV 60Hz_µA4.csv: -0.00162656009768926
# Lowest trough value in 90mV 60Hz_µA5.csv: -0.0035701423389695713
# Lowest trough value in 90mV 60Hz_µA6.csv: -0.014059852005544105
# Lowest trough value in 90mV 60Hz_µA7.csv: -0.0014811691725770716
# Lowest trough value in 90mV 60Hz_µA8.csv: -0.008759704226814883
# Lowest trough value in 90mV 80Hz_uA.csv: -0.005200394478359508
# Lowest trough value in 90mV 80Hz_µA1.csv: -0.005200394478359508
# Lowest trough value in 90mV 80Hz_µA2.csv: -0.0266364233752703
# Lowest trough value in 90mV 80Hz_µA3.csv: -0.009864364228028277
# Lowest trough value in 90mV 80Hz_µA4.csv: 0.0003050473782370555
# Lowest trough value in 90mV 80Hz_µA5.csv: -0.00648717680841723
# Lowest trough value in 90mV 80Hz_µA6.csv: -0.019288273717553733
# Lowest trough value in 90mV 80Hz_µA7.csv: 0.0021516952672057804
# Lowest trough value in 90mV 80Hz_µA8.csv: -0.01241692131185049
