# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Function to find the lowest point using a 3-point peak picking process
def find_lowest_point(data):
    n = len(data)
    lowest_value = data[0]  # Initialize with the first value
    lowest_index = 0
    
    # Iterate through the data to find the lowest point
    for i in range(1, n-1):
        if data[i] < data[i-1] and data[i] < data[i+1]:
            if data[i] < lowest_value:
                lowest_value = data[i]
                lowest_index = i
    
    return lowest_index, lowest_value

# Function to interpolate the baseline
def interpolate_baseline(data):
    if len(data) > 210:
        left_segment_mean = np.mean(data[:150])  # Mean of the first 150 points
        right_segment_mean = np.mean(data[-50:])  # Mean of the last 50 points
    else:
        left_segment_mean = np.mean(data[:20])  # Mean of the first 20 points
        right_segment_mean = np.mean(data[-20:])  # Mean of the last 20 points
    
    baseline_slope = (right_segment_mean - left_segment_mean) / (len(data) - 1)
    baseline_intercept = left_segment_mean
    
    baseline = baseline_intercept + baseline_slope * np.arange(len(data))
    
    return baseline

# Folder containing the CSV files
folder_path = r"C:\Users\kulma\OneDrive\Documents\School\MASc Year 1\Surface Profilometry Analyzer\Surface-Profilometry-Analyzer\Peak picking algorithm\extracted_csv_files\all_output_files"

# Initialize an empty list to store the results
results = []

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        data_frame = pd.read_csv(file_path)

        # Ensure that the CSV has exactly one column
        if data_frame.shape[1] != 1:
            raise ValueError(f"The CSV file {filename} must contain exactly one column.")

        # Convert data to numpy array and ensure all values are numeric
        data = pd.to_numeric(data_frame.iloc[:, 0], errors='coerce').values

        # Remove NaN values that may have been introduced by non-numeric entries
        data = data[~np.isnan(data)]

        # Debugging print statements
        print(f"Processing file: {filename}")
        print(f"Data loaded from CSV (first 10 values): {data[:10]}")
        print(f"Number of data points: {len(data)}")

        # Find the lowest point
        lowest_index, lowest_value = find_lowest_point(data)

        # Interpolate the baseline
        baseline = interpolate_baseline(data)

        # Calculate the normalized value of the lowest peak
        normalized_value = lowest_value - baseline[lowest_index]

        # Append the result to the list
        results.append((filename, normalized_value))

        # Plotting the data with the interpolated baseline
        plt.figure(figsize=(10, 6))
        plt.plot(data, marker='o', linestyle='-', color='b', label='Data')
        plt.plot(baseline, linestyle='--', color='r', label='Baseline')
        plt.scatter(lowest_index, lowest_value, color='g', s=100, label='Lowest Point')
        plt.vlines(lowest_index, lowest_value, baseline[lowest_index], color='r', linestyle='--')

        plt.title(f'Normalized Peak Relative to Interpolated Baseline - {filename}')
        plt.xlabel('Index')
        plt.ylabel('Value')
        plt.legend()

        plt.grid(True)
        plt.tight_layout()

        # Save the plot as a PNG file
        plot_filename = os.path.join(folder_path, f"{os.path.splitext(filename)[0]}_plot.png")
        plt.savefig(plot_filename)
        plt.close()  # Ensure the plot is closed properly

        print(f"Lowest value found: {lowest_value}")
        print(f"Normalized value of the lowest peak: {normalized_value}")

# Create a DataFrame from the results
results_df = pd.DataFrame(results, columns=['Filename', 'Normalized Value'])
results_df.set_index('Filename', inplace=True)

# Save the results to a CSV file
results_csv = os.path.join(folder_path, "normalized_values.csv")
results_df.to_csv(results_csv)

# Print the results
print("\nNormalized values of the lowest peaks:")
print(results_df)
# Out:
# Processing file: cleaned_100mV 100Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-3.8497591  -3.74247074 -3.69764805 -3.65807056 -3.61563206 -3.57557774
#  -3.52884769 -3.5083437  -3.46161366 -3.42680454]
# Number of data points: 504
# Lowest value found: -3.84975910186768
# Normalized value of the lowest peak: -1.840893840789799
# Processing file: cleaned_100mV 100Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-2.68293381 -2.64764786 -2.63143539 -2.6199913  -2.60568619 -2.59567261
#  -2.582798   -2.57564545 -2.56563187 -2.55275726]
# Number of data points: 504
# Lowest value found: -2.68293380737305
# Normalized value of the lowest peak: -0.6217972755432153
# Processing file: cleaned_100mV 100Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-1.11461163 -1.0860014  -1.07789516 -1.06597424 -1.06072903 -1.05453014
#  -1.04213238 -1.03688717 -1.0244894  -1.00970745]
# Number of data points: 504
# Lowest value found: -1.11461162567139
# Normalized value of the lowest peak: -0.47837044397990247
# Processing file: cleaned_100mV 100Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-3.20126057 -3.15977573 -3.13402653 -3.11494827 -3.09873581 -3.08013916
#  -3.06774139 -3.05057526 -3.02816391 -3.0100441 ]
# Number of data points: 504
# Lowest value found: -3.20126056671143
# Normalized value of the lowest peak: -0.8239856402079302
# Processing file: cleaned_100mV 100Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.84472179 -0.82612514 -0.81182003 -0.81086636 -0.80466747 -0.80466747
#  -0.79179287 -0.7832098  -0.77224255 -0.77414989]
# Number of data points: 504
# Lowest value found: -0.844721794128418
# Normalized value of the lowest peak: -0.261431630452474
# Processing file: cleaned_100mV 100Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-2.10739136 -2.05589294 -2.03014374 -2.00582504 -1.99295044 -1.96815491
#  -1.94383621 -1.93334579 -1.90616608 -1.88709259]
# Number of data points: 504
# Lowest value found: -2.10739135742188
# Normalized value of the lowest peak: -0.8787128130594939
# Processing file: cleaned_100mV 100Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-1.00970745 -0.99444866 -0.99349499 -0.98920345 -0.9872961  -0.98681927
#  -0.98634243 -0.98634243 -0.98491192 -0.98586559]
# Number of data points: 504
# Lowest value found: -1.35159969329834
# Normalized value of the lowest peak: 1.8088123505284563
# Processing file: cleaned_100mV 100Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-2.19083786 -2.13600159 -2.10882187 -2.08021164 -2.05636978 -2.03777313
#  -2.01440811 -1.99056625 -1.96720123 -1.94574356]
# Number of data points: 504
# Lowest value found: -2.19083786010742
# Normalized value of the lowest peak: -1.0489825248718243
# Processing file: cleaned_100mV 200Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-7.73933411 -7.54526138 -7.45895386 -7.3888588  -7.32257843 -7.22959518
#  -7.18286514 -7.10800171 -7.07128525 -6.96828842]
# Number of data points: 504
# Lowest value found: -7.73933410644531
# Normalized value of the lowest peak: -3.244154008229571
# Processing file: cleaned_100mV 200Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-4.49015617 -4.43198204 -4.3981266  -4.38477516 -4.36665058 -4.33327198
#  -4.33088779 -4.31133747 -4.28177357 -4.26126957]
# Number of data points: 504
# Lowest value found: -4.49015617370605
# Normalized value of the lowest peak: -0.9972066084543818
# Processing file: cleaned_100mV 200Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-1.93763733 -1.90187454 -1.87230587 -1.87039852 -1.86086178 -1.82986736
#  -1.8174696  -1.81651592 -1.79219723 -1.78838253]
# Number of data points: 504
# Lowest value found: -1.93763732910156
# Normalized value of the lowest peak: -0.7234191258748353
# Processing file: cleaned_100mV 200Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-4.86971855 -4.79914665 -4.77435112 -4.74240303 -4.71903801 -4.69042778
#  -4.67803001 -4.65895653 -4.63368416 -4.62176323]
# Number of data points: 504
# Lowest value found: -4.86971855163574
# Normalized value of the lowest peak: -1.0194944620132427
# Processing file: cleaned_100mV 200Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-1.83320522 -1.78981304 -1.79410458 -1.76597118 -1.75023556 -1.76120281
#  -1.73068523 -1.72734737 -1.71542645 -1.71208858]
# Number of data points: 504
# Lowest value found: -1.8332052230835
# Normalized value of the lowest peak: -0.4423685868581182
# Processing file: cleaned_100mV 200Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-3.04103851 -2.94376373 -2.92135239 -2.89035797 -2.85697937 -2.8612709
#  -2.81597137 -2.79403687 -2.77114868 -2.73252487]
# Number of data points: 504
# Lowest value found: -3.04103851318359
# Normalized value of the lowest peak: -1.1552712122599245
# Processing file: cleaned_100mV 200Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-1.66297436 -1.60432339 -1.62339687 -1.59144878 -1.60336971 -1.61576748
#  -1.60623074 -1.60098553 -1.60384655 -1.60873413]
# Number of data points: 504
# Lowest value found: -4.12584781646729
# Normalized value of the lowest peak: 2.1520903334860906
# Processing file: cleaned_100mV 200Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-3.31284046 -3.23034763 -3.1964922  -3.14880848 -3.11351776 -3.09921265
#  -3.05391312 -3.03340912 -2.9895401  -2.97046661]
# Number of data points: 504
# Lowest value found: -3.31284046173096
# Normalized value of the lowest peak: -1.4820508321126333
# Processing file: cleaned_100mV 20Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.16093254 -0.15997887 -0.15902519 -0.15854836 -0.15807152 -0.15854836
#  -0.15997887 -0.15997887 -0.1604557  -0.16140938]
# Number of data points: 202
# Lowest value found: -3.67428302764893
# Normalized value of the lowest peak: -0.28092327402599215
# Processing file: cleaned_100mV 20Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.60296059 -0.59628487 -0.59580803 -0.59533119 -0.59485435 -0.59485435
#  -0.59485435 -0.59485435 -0.59580803 -0.59485435]
# Number of data points: 202
# Lowest value found: -0.668768882751465
# Normalized value of the lowest peak: -0.002451370011514853
# Processing file: cleaned_100mV 20Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.05316734 -0.05412102 -0.05173683 -0.05125999 -0.05221367 -0.05269051
#  -0.05316734 -0.05173683 -0.05269051 -0.05316734]
# Number of data points: 202
# Lowest value found: -0.0727176666259766
# Normalized value of the lowest peak: 0.0066862770574009495
# Processing file: cleaned_100mV 20Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.83947659 -0.8332777  -0.83184719 -0.83232403 -0.83184719 -0.83041668
#  -0.83280087 -0.83184719 -0.8332777  -0.83375454]
# Number of data points: 202
# Lowest value found: -0.947718620300293
# Normalized value of the lowest peak: 0.036398095278005194
# Processing file: cleaned_100mV 20Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.09179115 -0.09083748 -0.08845329 -0.08940697 -0.08845329 -0.08893013
#  -0.08797646 -0.08940697 -0.08797646 -0.08893013]
# Number of data points: 202
# Lowest value found: -0.15711784362793
# Normalized value of the lowest peak: 0.06380176069724597
# Processing file: cleaned_100mV 20Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.24342537 -0.23818016 -0.23341179 -0.22864342 -0.22864342 -0.22768974
#  -0.22673607 -0.22578239 -0.22578239 -0.22673607]
# Number of data points: 202
# Lowest value found: -0.243425369262695
# Normalized value of the lowest peak: -0.015628337860107117
# Processing file: cleaned_100mV 20Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-1.24097347 -1.25384808 -1.27149105 -1.29104137 -1.30582333 -1.32108212
#  -1.33920193 -1.35446072 -1.37401104 -1.3940382 ]
# Number of data points: 202
# Lowest value found: -2.05923080444336
# Normalized value of the lowest peak: -0.29643649485573853
# Processing file: cleaned_100mV 20Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.13041496 -0.12660027 -0.12516975 -0.12564659 -0.12469292 -0.12421608
#  -0.12326241 -0.12135506 -0.12373924 -0.12230873]
# Number of data points: 202
# Lowest value found: -0.152349472045898
# Normalized value of the lowest peak: 0.07084353053154685
# Processing file: cleaned_100mV 300Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-13.4094286  -13.10901642 -12.99028397 -12.84103394 -12.7404213
#  -12.65411377 -12.54253387 -12.48340607 -12.35370636 -12.23640442]
# Number of data points: 504
# Lowest value found: -13.4094285964966
# Normalized value of the lowest peak: -5.037172412872332
# Processing file: cleaned_100mV 300Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-6.36746883 -6.27782345 -6.23347759 -6.21392727 -6.16481304 -6.14049435
#  -6.12618923 -6.09376431 -6.0808897  -6.02128506]
# Number of data points: 504
# Lowest value found: -6.36746883392334
# Normalized value of the lowest peak: -1.351383908589681
# Processing file: cleaned_100mV 300Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-2.9151535  -2.86651611 -2.86746979 -2.81215668 -2.7983284  -2.78831482
#  -2.77639389 -2.72918701 -2.75684357 -2.6981926 ]
# Number of data points: 504
# Lowest value found: -2.91515350341797
# Normalized value of the lowest peak: -0.947844219207765
# Processing file: cleaned_100mV 300Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-6.87530518 -6.75656796 -6.72175884 -6.69314861 -6.66835308 -6.6416502
#  -6.59921169 -6.60207272 -6.5582037  -6.54294491]
# Number of data points: 504
# Lowest value found: -6.87530517578125
# Normalized value of the lowest peak: -1.2943098386128744
# Processing file: cleaned_100mV 300Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-3.25132847 -3.16978931 -3.17169666 -3.15453053 -3.14022541 -3.12544346
#  -3.09110641 -3.10493469 -3.07727814 -3.04294586]
# Number of data points: 504
# Lowest value found: -3.25132846832275
# Normalized value of the lowest peak: -0.6306837081909138
# Processing file: cleaned_100mV 300Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-4.14396763 -4.07482624 -4.04383183 -3.96467686 -3.94131184 -3.9036417
#  -3.8459444  -3.83926868 -3.79015446 -3.76154423]
# Number of data points: 504
# Lowest value found: -4.143967628479
# Normalized value of the lowest peak: -1.5325496355692505
# Processing file: cleaned_100mV 300Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-2.23232269 -2.1836853  -2.16032028 -2.16890335 -2.18130112 -2.18082428
#  -2.17224121 -2.16938019 -2.16651917 -2.1631813 ]
# Number of data points: 504
# Lowest value found: -6.33838176727295
# Normalized value of the lowest peak: 1.2263042176931087
# Processing file: cleaned_100mV 300Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-4.24458027 -4.15445805 -4.10295963 -4.06004429 -4.0242815  -3.97373676
#  -3.93368244 -3.90078068 -3.89791965 -3.82162571]
# Number of data points: 504
# Lowest value found: -4.24458026885986
# Normalized value of the lowest peak: -1.715256786346432
# Processing file: cleaned_100mV 40Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.35738945 -0.35214424 -0.35214424 -0.34880638 -0.34928322 -0.34689903
#  -0.34880638 -0.3516674  -0.35071373 -0.35071373]
# Number of data points: 202
# Lowest value found: -0.382661819458008
# Normalized value of the lowest peak: 0.8430137681723824
# Processing file: cleaned_100mV 40Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.87476254 -0.8666563  -0.86617947 -0.86570263 -0.86522579 -0.86617947
#  -0.8666563  -0.86522579 -0.8666563  -0.86713314]
# Number of data points: 202
# Lowest value found: -0.901942253112793
# Normalized value of the lowest peak: 0.0267144459397044
# Processing file: cleaned_100mV 40Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.10323524 -0.10037422 -0.09989738 -0.1013279  -0.10085106 -0.10228157
#  -0.10037422 -0.10275841 -0.10228157 -0.10037422]
# Number of data points: 202
# Lowest value found: -0.14805793762207
# Normalized value of the lowest peak: -0.003905349702977151
# Processing file: cleaned_100mV 40Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-1.14274502 -1.13368511 -1.13368511 -1.13273144 -1.13273144 -1.1322546
#  -1.13285065 -1.13320827 -1.13320827 -1.13416195]
# Number of data points: 202
# Lowest value found: -1.29151821136475
# Normalized value of the lowest peak: 0.016973000853806264
# Processing file: cleaned_100mV 40Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.1680851  -0.16570091 -0.16617775 -0.16522408 -0.16617775 -0.1642704
#  -0.16522408 -0.16522408 -0.16522408 -0.16522408]
# Number of data points: 202
# Lowest value found: -0.272035598754883
# Normalized value of the lowest peak: 0.05633193462049163
# Processing file: cleaned_100mV 40Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.3926754  -0.38695335 -0.38266182 -0.37932396 -0.38266182 -0.38027763
#  -0.38027763 -0.38087368 -0.38123131 -0.38170815]
# Number of data points: 202
# Lowest value found: -0.428438186645508
# Normalized value of the lowest peak: 0.558006169191047
# Processing file: cleaned_100mV 40Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.79942226 -0.80132961 -0.80228329 -0.80705166 -0.81182003 -0.81754208
#  -0.82135677 -0.82517147 -0.83137035 -0.83756924]
# Number of data points: 202
# Lowest value found: -0.799422264099121
# Normalized value of the lowest peak: 0.0415325164794923
# Processing file: cleaned_100mV 40Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.20384789 -0.20003319 -0.19907951 -0.197649   -0.19717216 -0.19812584
#  -0.19669533 -0.19717216 -0.19621849 -0.19669533]
# Number of data points: 202
# Lowest value found: -0.360250473022461
# Normalized value of the lowest peak: -0.018778487817565137
# Processing file: cleaned_100mV 60Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-1.78456783 -1.73116207 -1.70732021 -1.68776989 -1.67108059 -1.65534496
#  -1.63627148 -1.62005901 -1.60146236 -1.58811092]
# Number of data points: 504
# Lowest value found: -6.31024837493896
# Normalized value of the lowest peak: -0.3455184387323271
# Processing file: cleaned_100mV 60Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-1.88804626 -1.8637228  -1.85370922 -1.84417248 -1.83320522 -1.82700634
#  -1.81842327 -1.81079388 -1.80364132 -1.79362774]
# Number of data points: 504
# Lowest value found: -1.88804626464844
# Normalized value of the lowest peak: -0.46347297032674395
# Processing file: cleaned_100mV 60Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.77605724 -0.75984478 -0.75030804 -0.73886395 -0.73123455 -0.72789669
#  -0.71979046 -0.71359158 -0.70310116 -0.69928646]
# Number of data points: 504
# Lowest value found: -0.776057243347168
# Normalized value of the lowest peak: -0.3602577845255534
# Processing file: cleaned_100mV 60Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-2.27333069 -2.23661423 -2.2208786  -2.21324921 -2.19799042 -2.18463898
#  -2.1708107  -2.16079712 -2.14839935 -2.1374321 ]
# Number of data points: 504
# Lowest value found: -2.27333068847656
# Normalized value of the lowest peak: -0.5912245432535781
# Processing file: cleaned_100mV 60Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.51617622 -0.5095005  -0.50139427 -0.49614906 -0.49328804 -0.48804283
#  -0.48327446 -0.48327446 -0.47755241 -0.46753883]
# Number of data points: 504
# Lowest value found: -0.516176223754883
# Normalized value of the lowest peak: -0.17941633860270206
# Processing file: cleaned_100mV 60Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-1.60336971 -1.56188488 -1.54185772 -1.52087688 -1.49941921 -1.48702145
#  -1.47128582 -1.45125866 -1.43552303 -1.41883373]
# Number of data points: 504
# Lowest value found: -1.60336971282959
# Normalized value of the lowest peak: -0.7269241650899253
# Processing file: cleaned_100mV 60Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.61297417 -0.60248375 -0.59914589 -0.59294701 -0.59342384 -0.5928278
#  -0.59199333 -0.59294701 -0.59151649 -0.59151649]
# Number of data points: 504
# Lowest value found: -1.29008769989014
# Normalized value of the lowest peak: 1.0941462032047593
# Processing file: cleaned_100mV 60Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-1.4646101  -1.42503262 -1.4069128  -1.38974667 -1.37258053 -1.35636806
#  -1.33920193 -1.32775784 -1.30820751 -1.29104137]
# Number of data points: 504
# Lowest value found: -1.46461009979248
# Normalized value of the lowest peak: -0.7295893669128416
# Processing file: cleaned_100mV 80Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-3.07584763 -2.98715591 -2.94471741 -2.91276932 -2.88129807 -2.84744263
#  -2.81597137 -2.79022217 -2.75970459 -2.7239418 ]
# Number of data points: 504
# Lowest value found: -3.07584762573242
# Normalized value of the lowest peak: -1.5008896191914858
# Processing file: cleaned_100mV 80Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-2.27762222 -2.24662781 -2.23613739 -2.22373962 -2.21324921 -2.20609665
#  -2.19274521 -2.18654633 -2.17605591 -2.16270447]
# Number of data points: 504
# Lowest value found: -2.27762222290039
# Normalized value of the lowest peak: -0.5290359497070307
# Processing file: cleaned_100mV 80Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.94008923 -0.92101574 -0.91624737 -0.90146542 -0.89383602 -0.88191509
#  -0.8781004  -0.86999416 -0.86093426 -0.85521221]
# Number of data points: 504
# Lowest value found: -0.940089225769043
# Normalized value of the lowest peak: -0.41758241653442385
# Processing file: cleaned_100mV 80Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-2.87891388 -2.83218384 -2.81024933 -2.79689789 -2.77305603 -2.76399612
#  -2.74778366 -2.73300171 -2.71249771 -2.68960953]
# Number of data points: 504
# Lowest value found: -2.87891387939453
# Normalized value of the lowest peak: -0.7985856056213358
# Processing file: cleaned_100mV 80Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.67115307 -0.65541744 -0.6496954  -0.64015865 -0.63539028 -0.63539028
#  -0.62633038 -0.62203407 -0.61535835 -0.613451  ]
# Number of data points: 504
# Lowest value found: -0.67115306854248
# Normalized value of the lowest peak: -0.2208532651265458
# Processing file: cleaned_100mV 80Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-1.86563015 -1.82605267 -1.79648876 -1.7802763  -1.763587   -1.74165249
#  -1.71924114 -1.70922756 -1.68824673 -1.66917324]
# Number of data points: 504
# Lowest value found: -1.86563014984131
# Normalized value of the lowest peak: -0.8012628555297865
# Processing file: cleaned_100mV 80Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.79656124 -0.78130245 -0.77891827 -0.77653408 -0.77414989 -0.77987194
#  -0.77760696 -0.77987194 -0.77653408 -0.77462673]
# Number of data points: 504
# Lowest value found: -4.4810962677002
# Normalized value of the lowest peak: 0.5975770722168612
# Processing file: cleaned_100mV 80Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-1.89138412 -1.84751034 -1.81890011 -1.79934978 -1.77693844 -1.75929546
#  -1.73354626 -1.72210217 -1.70064449 -1.68252468]
# Number of data points: 504
# Lowest value found: -1.89138412475586
# Normalized value of the lowest peak: -0.9122173627217617
# Processing file: cleaned_20mV 100Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.52857399 -0.52332878 -0.52237511 -0.51903725 -0.51999092 -0.51617622
#  -0.51379204 -0.51617622 -0.51188469 -0.51426888]
# Number of data points: 504
# Lowest value found: -0.612497329711914
# Normalized value of the lowest peak: -0.04353559198878776
# Processing file: cleaned_20mV 100Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.5261898  -0.51856041 -0.51426888 -0.50520897 -0.50330162 -0.49853325
#  -0.49710274 -0.49042702 -0.49471855 -0.48565865]
# Number of data points: 504
# Lowest value found: -0.526189804077148
# Normalized value of the lowest peak: -0.1843100786209102
# Processing file: cleaned_20mV 100Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.48136711 -0.47278404 -0.46849251 -0.46372414 -0.46133995 -0.45990944
#  -0.45847893 -0.4556179  -0.45323372 -0.44894218]
# Number of data points: 504
# Lowest value found: -0.481367111206055
# Normalized value of the lowest peak: -0.11906941731770865
# Processing file: cleaned_20mV 100Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.15282631 -0.15473366 -0.14996529 -0.15044212 -0.14901161 -0.14710426
#  -0.14710426 -0.14615059 -0.14472008 -0.14233589]
# Number of data points: 504
# Lowest value found: -0.154733657836914
# Normalized value of the lowest peak: -0.048741930916737466
# Processing file: cleaned_20mV 100Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.16283989 -0.15997887 -0.15950203 -0.15997887 -0.15807152 -0.15664101
#  -0.15902519 -0.15521049 -0.15425682 -0.15521049]
# Number of data points: 504
# Lowest value found: -0.162839889526367
# Normalized value of the lowest peak: -0.031306942303975266
# Processing file: cleaned_20mV 100Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.18239021 -0.17619133 -0.17428398 -0.17476082 -0.18000603 -0.17428398
#  -0.1809597  -0.16903877 -0.17237663 -0.17046928]
# Number of data points: 504
# Lowest value found: -0.400781631469727
# Normalized value of the lowest peak: -0.03787390991423323
# Processing file: cleaned_20mV 100Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.1270771  -0.12421608 -0.12516975 -0.12183189 -0.11754036 -0.12421608
#  -0.11563301 -0.1180172  -0.12516975 -0.12135506]
# Number of data points: 504
# Lowest value found: -0.196218490600586
# Normalized value of the lowest peak: -0.05237200309141657
# Processing file: cleaned_20mV 100Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.14138222 -0.13995171 -0.13804436 -0.13566017 -0.13566017 -0.1347065
#  -0.13661385 -0.13136864 -0.13375282 -0.13232231]
# Number of data points: 504
# Lowest value found: -0.23961067199707
# Normalized value of the lowest peak: -0.041936278106203845
# Processing file: cleaned_20mV 150Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.26202202 -0.25486946 -0.24724007 -0.2553463  -0.25105476 -0.24199486
#  -0.24485588 -0.24104118 -0.24151802 -0.23913383]
# Number of data points: 504
# Lowest value found: -0.262022018432617
# Normalized value of the lowest peak: -0.047873258590698076
# Processing file: cleaned_20mV 150Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.7960844  -0.78225613 -0.78082561 -0.77271938 -0.77701092 -0.75936794
#  -0.75126171 -0.75650692 -0.74172497 -0.74220181]
# Number of data points: 504
# Lowest value found: -0.796084403991699
# Normalized value of the lowest peak: -0.23678255081176736
# Processing file: cleaned_20mV 150Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.6382513  -0.62585354 -0.61869621 -0.6210804  -0.62060356 -0.613451
#  -0.60582161 -0.60772896 -0.60534477 -0.59580803]
# Number of data points: 504
# Lowest value found: -0.638251304626465
# Normalized value of the lowest peak: -0.15340659618377706
# Processing file: cleaned_20mV 150Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.21338463 -0.22292137 -0.20003319 -0.2052784  -0.20289421 -0.21529198
#  -0.20337105 -0.20861626 -0.21147728 -0.20623207]
# Number of data points: 504
# Lowest value found: -0.222921371459961
# Normalized value of the lowest peak: -0.0662659634968712
# Processing file: cleaned_20mV 150Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.65541744 -0.64301968 -0.642066   -0.63682079 -0.64158916 -0.63109875
#  -0.6330061  -0.63443661 -0.63443661 -0.62966824]
# Number of data points: 504
# Lowest value found: -0.756030082702637
# Normalized value of the lowest peak: -0.050428103784443956
# Processing file: cleaned_20mV 150Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.24867058 -0.24294853 -0.25105476 -0.24902821 -0.2515316  -0.25057793
#  -0.24724007 -0.24151802 -0.24247169 -0.24676323]
# Number of data points: 504
# Lowest value found: -0.568151473999023
# Normalized value of the lowest peak: -0.12318491856731073
# Processing file: cleaned_20mV 150Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.16951561 -0.16665459 -0.17571449 -0.16856194 -0.17285347 -0.16331673
#  -0.15902519 -0.17285347 -0.1718998  -0.17046928]
# Number of data points: 504
# Lowest value found: -0.275850296020508
# Normalized value of the lowest peak: -0.03379695063161897
# Processing file: cleaned_20mV 150Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.18954277 -0.19526482 -0.1938343  -0.18191338 -0.17857552 -0.18286705
#  -0.18048286 -0.17571449 -0.16999245 -0.16951561]
# Number of data points: 504
# Lowest value found: -0.286340713500977
# Normalized value of the lowest peak: -0.024823429886279225
# Processing file: cleaned_20mV 200Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.30970573 -0.29778481 -0.31208992 -0.30207634 -0.28824806 -0.29301643
#  -0.29921532 -0.30207634 -0.31447411 -0.31113625]
# Number of data points: 504
# Lowest value found: -0.821356773376465
# Normalized value of the lowest peak: -0.197565017937824
# Processing file: cleaned_20mV 200Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-1.11794949 -1.07741833 -1.09935284 -1.09315395 -1.07169628 -1.06215954
#  -1.05119228 -1.05977535 -1.0526228  -1.05357647]
# Number of data points: 504
# Lowest value found: -1.11794948577881
# Normalized value of the lowest peak: -0.2796789010365818
# Processing file: cleaned_20mV 200Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.80562115 -0.78416348 -0.79274654 -0.77748775 -0.76604366 -0.75984478
#  -0.7665205  -0.75698376 -0.74220181 -0.74649334]
# Number of data points: 504
# Lowest value found: -0.805621147155762
# Normalized value of the lowest peak: -0.18708753585815463
# Processing file: cleaned_20mV 200Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.30493736 -0.29826164 -0.28347969 -0.28252602 -0.29492378 -0.27775764
#  -0.28586388 -0.29730797 -0.2682209  -0.28920174]
# Number of data points: 504
# Lowest value found: -0.304937362670898
# Normalized value of the lowest peak: -0.08310993512471468
# Processing file: cleaned_20mV 200Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.80228329 -0.79751492 -0.79513073 -0.79465389 -0.79560757 -0.78607082
#  -0.79131603 -0.78273296 -0.76985836 -0.78034878]
# Number of data points: 504
# Lowest value found: -0.933890342712402
# Normalized value of the lowest peak: -0.0631917907434868
# Processing file: cleaned_20mV 200Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.37407875 -0.37789345 -0.36501884 -0.36931038 -0.36549568 -0.36787987
#  -0.36168098 -0.35309792 -0.35071373 -0.38027763]
# Number of data points: 504
# Lowest value found: -0.38456916809082
# Normalized value of the lowest peak: -0.03314737771187781
# Processing file: cleaned_20mV 200Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.19192696 -0.21243095 -0.19526482 -0.21910667 -0.19907951 -0.19478798
#  -0.19431114 -0.19288063 -0.20384789 -0.21290779]
# Number of data points: 504
# Lowest value found: -0.80228328704834
# Normalized value of the lowest peak: -0.13182945279904446
# Processing file: cleaned_20mV 200Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.26774406 -0.24676323 -0.23913383 -0.23722649 -0.23961067 -0.24199486
#  -0.2361536  -0.22816658 -0.2348423  -0.24199486]
# Number of data points: 504
# Lowest value found: -0.404596328735352
# Normalized value of the lowest peak: -0.06511404152497985
# Processing file: cleaned_20mV 20Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.03933907 -0.0398159  -0.03933907 -0.03790855 -0.03790855 -0.03802776
#  -0.03793836 -0.03790855 -0.03790855 -0.03790855]
# Number of data points: 202
# Lowest value found: -0.0588893890380859
# Normalized value of the lowest peak: -0.01629054991166981
# Processing file: cleaned_20mV 20Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.13327599 -0.13184547 -0.13041496 -0.1308918  -0.1308918  -0.13041496
#  -0.13041496 -0.1308918  -0.1308918  -0.13136864]
# Number of data points: 202
# Lowest value found: -0.152826309204102
# Normalized value of the lowest peak: -0.010813528032445674
# Processing file: cleaned_20mV 20Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.0193119  -0.01835823 -0.01740456 -0.01883507 -0.01883507 -0.01883507
#  -0.01835823 -0.01835823 -0.01835823 -0.01835823]
# Number of data points: 202
# Lowest value found: -0.0283718109130859
# Normalized value of the lowest peak: -0.0059822898599045556
# Processing file: cleaned_20mV 20Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.25200844 -0.24867058 -0.2477169  -0.2477169  -0.2477169  -0.24724007
#  -0.24676323 -0.2477169  -0.24676323 -0.24819374]
# Number of data points: 202
# Lowest value found: -0.27918815612793
# Normalized value of the lowest peak: -0.0026635269620529645
# Processing file: cleaned_20mV 20Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.02837181 -0.02932549 -0.02980232 -0.02980232 -0.02980232 -0.03027916
#  -0.03027916 -0.03051758 -0.030756   -0.030756  ]
# Number of data points: 202
# Lowest value found: -0.0426769256591797
# Normalized value of the lowest peak: -0.0022763933115337864
# Processing file: cleaned_20mV 20Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.04935265 -0.04887581 -0.04792213 -0.04935265 -0.04839897 -0.04839897
#  -0.04696846 -0.04887581 -0.0474453  -0.04887581]
# Number of data points: 202
# Lowest value found: -0.0813007354736328
# Normalized value of the lowest peak: -0.029079742099515228
# Processing file: cleaned_20mV 20Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.03314018 -0.03170967 -0.03266335 -0.03218651 -0.03170967 -0.03218651
#  -0.03314018 -0.03218651 -0.03170967 -0.03218651]
# Number of data points: 202
# Lowest value found: -0.0498294830322266
# Normalized value of the lowest peak: -0.015188864807584433
# Processing file: cleaned_20mV 20Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.03647804 -0.03600121 -0.03600121 -0.03552437 -0.03600121 -0.03552437
#  -0.03504753 -0.03695488 -0.03743172 -0.03647804]
# Number of data points: 202
# Lowest value found: -0.0736713409423828
# Normalized value of the lowest peak: 0.025442346411557973
# Processing file: cleaned_20mV 20Hz_µA_9.csv
# Data loaded from CSV (first 10 values): [ 0.00000000e+00 -1.04132177e-03 -7.97453462e-04  0.00000000e+00
#   0.00000000e+00 -7.09998602e-05 -4.38332386e-06  0.00000000e+00
#  -1.65566476e-05 -3.82963966e-05]
# Number of data points: 202
# Lowest value found: -0.0177832468844489
# Normalized value of the lowest peak: -0.017078208916823438
# Processing file: cleaned_20mV 300Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.30446053 -0.29587746 -0.26392937 -0.29444695 -0.2758503  -0.29778481
#  -0.28443336 -0.30446053 -0.27728081 -0.30589104]
# Number of data points: 504
# Lowest value found: -1.08075618743896
# Normalized value of the lowest peak: -0.18932730255733188
# Processing file: cleaned_20mV 300Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-1.93239212 -1.89567566 -1.88947678 -1.89043045 -1.87517166 -1.85132504
#  -1.8432188  -1.82700634 -1.84560299 -1.81603909]
# Number of data points: 504
# Lowest value found: -1.93239212036133
# Normalized value of the lowest peak: -0.37364725271860944
# Processing file: cleaned_20mV 300Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-1.13034725 -1.10841274 -1.09839916 -1.08075619 -1.11270428 -1.07074261
#  -1.07503414 -1.06645107 -1.06597424 -1.0616827 ]
# Number of data points: 504
# Lowest value found: -1.13034725189209
# Normalized value of the lowest peak: -0.23328185081481956
# Processing file: cleaned_20mV 300Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.5004406  -0.4594326  -0.46753883 -0.47278404 -0.47016144 -0.47373772
#  -0.46658516 -0.46181679 -0.46944618 -0.45228004]
# Number of data points: 504
# Lowest value found: -0.50044059753418
# Normalized value of the lowest peak: -0.1208557685216271
# Processing file: cleaned_20mV 300Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-1.11842632 -1.11461163 -1.11127377 -1.10459805 -1.08743191 -1.10888958
#  -1.12557888 -1.09220028 -1.0912466  -1.10078335]
# Number of data points: 504
# Lowest value found: -1.24001979827881
# Normalized value of the lowest peak: -0.049891577721275615
# Processing file: cleaned_20mV 300Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.69499493 -0.67878246 -0.68164349 -0.67306042 -0.68402767 -0.66447735
#  -0.66304684 -0.66352367 -0.67401409 -0.6663847 ]
# Number of data points: 504
# Lowest value found: -0.698332786560059
# Normalized value of the lowest peak: -0.04567890312594303
# Processing file: cleaned_20mV 300Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.44322014 -0.40841103 -0.41651726 -0.40555    -0.41508675 -0.41031837
#  -0.40745735 -0.42748451 -0.43749809 -0.41842461]
# Number of data points: 504
# Lowest value found: -0.935320854187012
# Normalized value of the lowest peak: -0.15217172459627037
# Processing file: cleaned_20mV 300Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.37407875 -0.3798008  -0.39696693 -0.40459633 -0.39601326 -0.39410591
#  -0.39076805 -0.39029121 -0.39458275 -0.39029121]
# Number of data points: 504
# Lowest value found: -0.598669052124023
# Normalized value of the lowest peak: -0.0859292292926701
# Processing file: cleaned_20mV 40Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.05984306 -0.05745888 -0.05698204 -0.05888939 -0.05888939 -0.0603199
#  -0.05984306 -0.05888939 -0.05936623 -0.05888939]
# Number of data points: 202
# Lowest value found: -0.124692916870117
# Normalized value of the lowest peak: -0.05559132466861838
# Processing file: cleaned_20mV 40Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.16903877 -0.16665459 -0.16379356 -0.16570091 -0.1642704  -0.1642704
#  -0.16522408 -0.16522408 -0.16522408 -0.16522408]
# Number of data points: 202
# Lowest value found: -0.210046768188477
# Normalized value of the lowest peak: -0.0329843207971377
# Processing file: cleaned_20mV 40Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.0231266  -0.02121925 -0.02074242 -0.0231266  -0.02026558 -0.02217293
#  -0.02169609 -0.02121925 -0.02074242 -0.02133846]
# Number of data points: 202
# Lowest value found: -0.0469684600830078
# Normalized value of the lowest peak: -0.015948305082558387
# Processing file: cleaned_20mV 40Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.31542778 -0.31018257 -0.31065941 -0.31113625 -0.31065941 -0.31208992
#  -0.31065941 -0.31113625 -0.31113625 -0.31161308]
# Number of data points: 202
# Lowest value found: -0.41508674621582
# Normalized value of the lowest peak: -0.0005825241999836139
# Processing file: cleaned_20mV 40Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.0436306  -0.0436306  -0.04267693 -0.0436306  -0.04601479 -0.04553795
#  -0.04649162 -0.0474453  -0.04696846 -0.04696846]
# Number of data points: 202
# Lowest value found: -0.0631809234619141
# Normalized value of the lowest peak: -0.004037221272786495
# Processing file: cleaned_20mV 40Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.0936985  -0.09179115 -0.09655952 -0.09703636 -0.0975132  -0.1013279
#  -0.10085106 -0.10466576 -0.10609627 -0.10895729]
# Number of data points: 202
# Lowest value found: -0.154733657836914
# Normalized value of the lowest peak: -0.040175665670366414
# Processing file: cleaned_20mV 40Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.04267693 -0.04220009 -0.04410744 -0.04315376 -0.04458427 -0.04410744
#  -0.04267693 -0.04220009 -0.04315376 -0.04267693]
# Number of data points: 202
# Lowest value found: -0.0894069671630859
# Normalized value of the lowest peak: -0.03990970589035181
# Processing file: cleaned_20mV 40Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.05555153 -0.05841255 -0.05602837 -0.05412102 -0.05364418 -0.05364418
#  -0.05424023 -0.05459785 -0.05507469 -0.05555153]
# Number of data points: 202
# Lowest value found: -0.12516975402832
# Normalized value of the lowest peak: 0.18727067691176716
# Processing file: cleaned_20mV 60Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.34117699 -0.34165382 -0.33354759 -0.33354759 -0.33307076 -0.32877922
#  -0.32877922 -0.32544136 -0.32353401 -0.32401085]
# Number of data points: 504
# Lowest value found: -0.341653823852539
# Normalized value of the lowest peak: -0.08344601684251785
# Processing file: cleaned_20mV 60Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.31733513 -0.31590462 -0.31065941 -0.30875206 -0.30446053 -0.29778481
#  -0.29587746 -0.29444695 -0.29301643 -0.28920174]
# Number of data points: 504
# Lowest value found: -0.31733512878418
# Normalized value of the lowest peak: -0.12814521789550815
# Processing file: cleaned_20mV 60Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.0975132  -0.0936985  -0.09799004 -0.09417534 -0.09322166 -0.09274483
#  -0.09274483 -0.09179115 -0.08893013 -0.08940697]
# Number of data points: 504
# Lowest value found: -0.0979900360107422
# Normalized value of the lowest peak: -0.03550150048424664
# Processing file: cleaned_20mV 60Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.38313866 -0.37837029 -0.37789345 -0.37753582 -0.37693977 -0.37693977
#  -0.37693977 -0.37574768 -0.37503242 -0.37407875]
# Number of data points: 504
# Lowest value found: -0.533819198608398
# Normalized value of the lowest peak: 0.022210685206692338
# Processing file: cleaned_20mV 60Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.09465218 -0.09179115 -0.09179115 -0.09119511 -0.09131432 -0.0898838
#  -0.08893013 -0.08940697 -0.08702278 -0.08702278]
# Number of data points: 504
# Lowest value found: -0.0946521759033203
# Normalized value of the lowest peak: -0.02355655034383136
# Processing file: cleaned_20mV 60Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.2014637  -0.19907951 -0.19669533 -0.19669533 -0.19478798 -0.19049644
#  -0.19001961 -0.18668175 -0.19049644 -0.1847744 ]
# Number of data points: 504
# Lowest value found: -0.223875045776367
# Normalized value of the lowest peak: -0.08865031601973428
# Processing file: cleaned_20mV 60Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.12326241 -0.12135506 -0.12230873 -0.11849403 -0.11754036 -0.1180172
#  -0.1180172  -0.11658669 -0.1142025  -0.11610985]
# Number of data points: 504
# Lowest value found: -0.130414962768555
# Normalized value of the lowest peak: -0.039318039213450076
# Processing file: cleaned_20mV 60Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.10323524 -0.10037422 -0.10418892 -0.09703636 -0.09799004 -0.09608269
#  -0.09608269 -0.09572506 -0.09608269 -0.09465218]
# Number of data points: 504
# Lowest value found: -0.199079513549805
# Normalized value of the lowest peak: -0.042944829775214605
# Processing file: cleaned_20mV 80Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.12230873 -0.12564659 -0.12373924 -0.11992455 -0.12135506 -0.11515617
#  -0.12278557 -0.11706352 -0.10943413 -0.1142025 ]
# Number of data points: 504
# Lowest value found: -0.125646591186523
# Normalized value of the lowest peak: -0.04272131512226646
# Processing file: cleaned_20mV 80Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.41365623 -0.40555    -0.40507317 -0.39744377 -0.39458275 -0.38933754
#  -0.38933754 -0.38564205 -0.38218498 -0.38170815]
# Number of data points: 504
# Lowest value found: -0.413656234741211
# Normalized value of the lowest peak: -0.15709877014160162
# Processing file: cleaned_20mV 80Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.41031837 -0.40555    -0.40268898 -0.39935112 -0.39887428 -0.39553642
#  -0.39219856 -0.38743019 -0.38743019 -0.38647652]
# Number of data points: 504
# Lowest value found: -0.410318374633789
# Normalized value of the lowest peak: -0.10149717330932612
# Processing file: cleaned_20mV 80Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.45371056 -0.446558   -0.446558   -0.44703484 -0.446558   -0.44322014
#  -0.4427433  -0.44226646 -0.44035912 -0.4389286 ]
# Number of data points: 504
# Lowest value found: -0.583887100219727
# Normalized value of the lowest peak: -0.042383130059644
# Processing file: cleaned_20mV 80Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.12183189 -0.12516975 -0.12612343 -0.12183189 -0.12135506 -0.12040138
#  -0.12230873 -0.11515617 -0.11897087 -0.11515617]
# Number of data points: 504
# Lowest value found: -0.126123428344727
# Normalized value of the lowest peak: -0.027168340995819357
# Processing file: cleaned_20mV 80Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.26679039 -0.26345253 -0.25582314 -0.25629997 -0.25367737 -0.25105476
#  -0.2515316  -0.2515316  -0.24533272 -0.24294853]
# Number of data points: 504
# Lowest value found: -0.279664993286133
# Normalized value of the lowest peak: -0.08680136018908538
# Processing file: cleaned_20mV 80Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.10037422 -0.09560585 -0.09894371 -0.09655952 -0.0975132  -0.0975132
#  -0.09512901 -0.09465218 -0.09608269 -0.09632111]
# Number of data points: 504
# Lowest value found: -0.237703323364258
# Normalized value of the lowest peak: -0.039769334458135824
# Processing file: cleaned_20mV 80Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.12326241 -0.11610985 -0.11944771 -0.12040138 -0.12135506 -0.11610985
#  -0.11849403 -0.11467934 -0.11467934 -0.11610985]
# Number of data points: 504
# Lowest value found: -0.200986862182617
# Normalized value of the lowest peak: -0.032656891129520776
# Processing file: cleaned_30mV 100Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.70786953 -0.69308758 -0.683074   -0.67639828 -0.67687511 -0.66829205
#  -0.66733837 -0.66447735 -0.6496954  -0.64683437]
# Number of data points: 504
# Lowest value found: -0.707869529724121
# Normalized value of the lowest peak: -0.24629389444986965
# Processing file: cleaned_30mV 100Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.68021297 -0.67115307 -0.66161633 -0.65827847 -0.65732479 -0.65207958
#  -0.65303326 -0.64445019 -0.64445019 -0.64445019]
# Number of data points: 504
# Lowest value found: -0.68021297454834
# Normalized value of the lowest peak: -0.14479986826578783
# Processing file: cleaned_30mV 100Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.24533272 -0.238657   -0.24247169 -0.23627281 -0.23388863 -0.23341179
#  -0.23055077 -0.23150444 -0.22864342 -0.22864342]
# Number of data points: 504
# Lowest value found: -0.245332717895508
# Normalized value of the lowest peak: -0.0832351048787437
# Processing file: cleaned_30mV 100Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-1.057868   -1.0449934  -1.03450298 -1.02782726 -1.01972103 -1.0154295
#  -1.00923061 -1.00112438 -0.99921703 -0.99158764]
# Number of data points: 504
# Lowest value found: -1.05786800384521
# Normalized value of the lowest peak: -0.2692031860351515
# Processing file: cleaned_30mV 100Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.22435188 -0.21958351 -0.21910667 -0.21529198 -0.21576881 -0.21719933
#  -0.22244453 -0.22101402 -0.21529198 -0.21100044]
# Number of data points: 504
# Lowest value found: -0.242948532104492
# Normalized value of the lowest peak: -0.023116414479027375
# Processing file: cleaned_30mV 100Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.3464222  -0.3426075  -0.33545494 -0.33640862 -0.33664703 -0.33658743
#  -0.33640862 -0.33347309 -0.33116341 -0.32973289]
# Number of data points: 504
# Lowest value found: -0.550985336303711
# Normalized value of the lowest peak: 1.4008683303952454
# Processing file: cleaned_30mV 100Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.17094612 -0.17666817 -0.16856194 -0.17285347 -0.17142296 -0.17094612
#  -0.16951561 -0.17476082 -0.17237663 -0.16999245]
# Number of data points: 504
# Lowest value found: -0.478506088256836
# Normalized value of the lowest peak: 0.4464137510719322
# Processing file: cleaned_30mV 100Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.21147728 -0.21243095 -0.20337105 -0.19907951 -0.20003319 -0.19907951
#  -0.19907951 -0.20051003 -0.20003319 -0.19240379]
# Number of data points: 504
# Lowest value found: -0.361204147338867
# Normalized value of the lowest peak: -0.04285283796513911
# Processing file: cleaned_30mV 150Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-1.08886242 -1.06645107 -1.06359005 -1.04737759 -1.04403973 -1.0244894
#  -1.01733685 -1.01304531 -1.01876736 -1.00923061]
# Number of data points: 504
# Lowest value found: -1.08886241912842
# Normalized value of the lowest peak: -0.31882667740186255
# Processing file: cleaned_30mV 150Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.8947897  -0.89765072 -0.88811398 -0.88954449 -0.87714672 -0.8742857
#  -0.87380886 -0.86951733 -0.87476254 -0.85425854]
# Number of data points: 504
# Lowest value found: -0.897650718688965
# Normalized value of the lowest peak: -0.1737325960946764
# Processing file: cleaned_30mV 150Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.33545494 -0.33736229 -0.32830238 -0.32162666 -0.32687187 -0.32877922
#  -0.32484531 -0.31924248 -0.32448769 -0.31352043]
# Number of data points: 504
# Lowest value found: -0.337362289428711
# Normalized value of the lowest peak: -0.09937709020888913
# Processing file: cleaned_30mV 150Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-1.41501904 -1.41215801 -1.39117718 -1.38688564 -1.37305737 -1.37544155
#  -1.36113644 -1.34206295 -1.33729458 -1.34969234]
# Number of data points: 504
# Lowest value found: -1.41501903533936
# Normalized value of the lowest peak: -0.367863972981775
# Processing file: cleaned_30mV 150Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.3631115  -0.34594536 -0.36025047 -0.35023689 -0.34832954 -0.3426075
#  -0.34880638 -0.3464222  -0.34928322 -0.34928322]
# Number of data points: 504
# Lowest value found: -0.379323959350586
# Normalized value of the lowest peak: -0.034967837071402996
# Processing file: cleaned_30mV 150Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.41508675 -0.40316582 -0.40793419 -0.40125847 -0.40364265 -0.41890144
#  -0.40793419 -0.3964901  -0.39982796 -0.39172173]
# Number of data points: 504
# Lowest value found: -1.24192714691162
# Normalized value of the lowest peak: 0.749940507059623
# Processing file: cleaned_30mV 150Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.22244453 -0.22578239 -0.22721291 -0.23198128 -0.22864342 -0.23126602
#  -0.23198128 -0.23245811 -0.22912025 -0.2348423 ]
# Number of data points: 504
# Lowest value found: -1.55425548553467
# Normalized value of the lowest peak: -0.2714322385920702
# Processing file: cleaned_30mV 150Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.27489662 -0.2758503  -0.27537346 -0.26679039 -0.26726723 -0.28014183
#  -0.27012825 -0.259161   -0.26392937 -0.2553463 ]
# Number of data points: 504
# Lowest value found: -0.46229362487793
# Normalized value of the lowest peak: -0.06227806279641923
# Processing file: cleaned_30mV 200Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-1.52421474 -1.46699429 -1.49178982 -1.48272991 -1.45316601 -1.44649029
#  -1.45030499 -1.42121792 -1.43933773 -1.4183569 ]
# Number of data points: 504
# Lowest value found: -1.52421474456787
# Normalized value of the lowest peak: -0.3689682483673087
# Processing file: cleaned_30mV 200Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-1.16277218 -1.14179134 -1.11938    -1.13273144 -1.12367153 -1.12271786
#  -1.11651897 -1.11318111 -1.10173702 -1.098876  ]
# Number of data points: 504
# Lowest value found: -1.1627721786499
# Normalized value of the lowest peak: -0.23348808288573975
# Processing file: cleaned_30mV 200Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.4632473  -0.46086311 -0.45597553 -0.45275688 -0.44703484 -0.4376173
#  -0.42128563 -0.42939186 -0.42653084 -0.43606758]
# Number of data points: 504
# Lowest value found: -0.463247299194336
# Normalized value of the lowest peak: -0.13100941975911456
# Processing file: cleaned_30mV 200Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-1.7931509  -1.76978588 -1.73354626 -1.74022198 -1.73545361 -1.69969082
#  -1.70016766 -1.68967724 -1.67441845 -1.67775631]
# Number of data points: 504
# Lowest value found: -1.79315090179443
# Normalized value of the lowest peak: -0.4704109827677374
# Processing file: cleaned_30mV 200Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.52237511 -0.50663948 -0.51379204 -0.52905083 -0.53906441 -0.51808357
#  -0.50520897 -0.51045418 -0.50294399 -0.49853325]
# Number of data points: 504
# Lowest value found: -0.541448593139648
# Normalized value of the lowest peak: -0.03650491169701309
# Processing file: cleaned_30mV 200Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.49376488 -0.48565865 -0.47802925 -0.47719479 -0.47278404 -0.47230721
#  -0.47111511 -0.46902895 -0.46610832 -0.46658516]
# Number of data points: 504
# Lowest value found: -1.60718441009521
# Normalized value of the lowest peak: 0.3157393687446093
# Processing file: cleaned_30mV 200Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.30255318 -0.31352043 -0.30350685 -0.30398369 -0.30112267 -0.3015995
#  -0.29730797 -0.30064583 -0.28824806 -0.30779839]
# Number of data points: 504
# Lowest value found: -1.08314037322998
# Normalized value of the lowest peak: 0.22732857942107199
# Processing file: cleaned_30mV 200Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.36931038 -0.36120415 -0.34594536 -0.36072731 -0.35786629 -0.36025047
#  -0.35738945 -0.36072731 -0.35119057 -0.33020973]
# Number of data points: 504
# Lowest value found: -0.56767463684082
# ...
# Number of data points: 504
# Lowest value found: -3.96753787994385
# Normalized value of the lowest peak: -0.8278762499491399
# Processing file: cleaned_90mV 200Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-1.71304226 -1.66917324 -1.63388729 -1.63388729 -1.61242962 -1.61672115
#  -1.58048153 -1.58477306 -1.57380581 -1.53804302]
# Number of data points: 504
# Lowest value found: -1.71304225921631
# Normalized value of the lowest peak: -0.6343388557434095
# Processing file: cleaned_90mV 200Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-5.08667946 -5.00800133 -4.96079445 -4.94076729 -4.90595818 -4.88211632
#  -4.84015465 -4.81631279 -4.80153084 -4.75193977]
# Number of data points: 504
# Lowest value found: -5.08667945861816
# Normalized value of the lowest peak: -1.3506889343261674
# Processing file: cleaned_90mV 200Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-1.63102627 -1.58763409 -1.60384655 -1.59144878 -1.56426907 -1.55950069
#  -1.57332897 -1.55520916 -1.53804302 -1.53613567]
# Number of data points: 504
# Lowest value found: -1.63102626800537
# Normalized value of the lowest peak: -0.3640572230021146
# Processing file: cleaned_90mV 200Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-2.56896973 -2.4993515  -2.48552322 -2.47646332 -2.44213104 -2.41638184
#  -2.38824844 -2.3415184  -2.32625961 -2.32006073]
# Number of data points: 504
# Lowest value found: -2.5689697265625
# Normalized value of the lowest peak: -0.9452983220418294
# Processing file: cleaned_90mV 200Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-1.50895596 -1.48749828 -1.49655819 -1.48368359 -1.48892879 -1.48082256
#  -1.46365643 -1.48225307 -1.49703503 -1.45984173]
# Number of data points: 504
# Lowest value found: -6.96447372436523
# Normalized value of the lowest peak: 0.9314078760115541
# Processing file: cleaned_90mV 200Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-2.54798889 -2.5031662  -2.47360229 -2.45119095 -2.41447449 -2.40350723
#  -2.36249924 -2.34771729 -2.31624603 -2.30098724]
# Number of data points: 504
# Lowest value found: -2.54798889160156
# Normalized value of the lowest peak: -1.1050858497619604
# Processing file: cleaned_90mV 20Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.177145   -0.17571449 -0.17619133 -0.17571449 -0.17523766 -0.17905235
#  -0.17809868 -0.1809597  -0.18143654 -0.18382072]
# Number of data points: 202
# Lowest value found: -3.13879489898682
# Normalized value of the lowest peak: -0.89154779614501
# Processing file: cleaned_90mV 20Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.53095818 -0.5261898  -0.52571297 -0.52475929 -0.52380562 -0.52428246
#  -0.52332878 -0.52475929 -0.52428246 -0.52428246]
# Number of data points: 202
# Lowest value found: -0.592470169067383
# Normalized value of the lowest peak: -0.003144634303762217
# Processing file: cleaned_90mV 20Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.04839897 -0.04792213 -0.04839897 -0.0474453  -0.04696846 -0.04696846
#  -0.04756451 -0.04839897 -0.04792213 -0.04601479]
# Number of data points: 202
# Lowest value found: -0.0765323638916016
# Normalized value of the lowest peak: -0.003742637918956279
# Processing file: cleaned_90mV 20Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-0.74840069 -0.74363232 -0.74172497 -0.74124813 -0.74124813 -0.74220181
#  -0.74172497 -0.74267864 -0.74267864 -0.74267864]
# Number of data points: 202
# Lowest value found: -0.82517147064209
# Normalized value of the lowest peak: 0.07718285517906054
# Processing file: cleaned_90mV 20Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.08320808 -0.08177757 -0.08225441 -0.08177757 -0.08177757 -0.08165836
#  -0.08130074 -0.08115172 -0.0808239  -0.0808239 ]
# Number of data points: 202
# Lowest value found: -0.179052352905273
# Normalized value of the lowest peak: 0.037675784594977585
# Processing file: cleaned_90mV 20Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.21481514 -0.21004677 -0.20813942 -0.20670891 -0.20718575 -0.20623207
#  -0.20432472 -0.20480156 -0.20432472 -0.20480156]
# Number of data points: 202
# Lowest value found: -0.249147415161133
# Normalized value of the lowest peak: 0.6493794123331704
# Processing file: cleaned_90mV 20Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.93961239 -0.94628811 -0.9615469  -0.97156048 -0.98252773 -0.99397182
#  -1.00446224 -1.01495266 -1.02639675 -1.03784084]
# Number of data points: 202
# Lowest value found: -1.98007583618164
# Normalized value of the lowest peak: 0.1973432747285757
# Processing file: cleaned_90mV 20Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.12278557 -0.12135506 -0.11944771 -0.11849403 -0.11706352 -0.11754036
#  -0.11658669 -0.11610985 -0.11706352 -0.11563301]
# Number of data points: 202
# Lowest value found: -0.150918960571289
# Normalized value of the lowest peak: 0.15441214860375257
# Processing file: cleaned_90mV 300Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-11.59076214 -11.37141705 -11.20357037 -11.12679958 -11.05432034
#  -10.94083309 -10.86215496 -10.76106548 -10.64376354 -10.60513496]
# Number of data points: 504
# Lowest value found: -11.5907621383667
# Normalized value of the lowest peak: -4.236662228902181
# Processing file: cleaned_90mV 300Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-5.64649105 -5.54730415 -5.5196476  -5.49389839 -5.48150063 -5.46147346
#  -5.43381691 -5.3990078  -5.39328575 -5.3785038 ]
# Number of data points: 504
# Lowest value found: -5.64649105072021
# Normalized value of the lowest peak: -1.1115389823913526
# Processing file: cleaned_90mV 300Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-2.59471893 -2.52891541 -2.49172211 -2.50650406 -2.48027802 -2.46501923
#  -2.43164062 -2.41495132 -2.41161346 -2.3787117 ]
# Number of data points: 504
# Lowest value found: -2.59471893310547
# Normalized value of the lowest peak: -0.8343702236811332
# Processing file: cleaned_90mV 300Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-7.18667984 -7.06794739 -7.02646255 -6.97496414 -6.94063187 -6.90248489
#  -6.86433315 -6.81855679 -6.79042339 -6.7289114 ]
# Number of data points: 504
# Lowest value found: -7.18667984008789
# Normalized value of the lowest peak: -1.770986755688984
# Processing file: cleaned_90mV 300Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-2.90752411 -2.87509918 -2.8612709  -2.82264709 -2.80738831 -2.81740189
#  -2.81740189 -2.77925491 -2.78688431 -2.76542664]
# Number of data points: 504
# Lowest value found: -2.90752410888672
# Normalized value of the lowest peak: -0.5197739601135258
# Processing file: cleaned_90mV 300Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-3.20221424 -3.1478548  -3.1101799  -3.08586121 -3.06249619 -3.03007126
#  -2.99716949 -2.98524857 -2.9485321  -2.9227829 ]
# Number of data points: 504
# Lowest value found: -3.20221424102783
# Normalized value of the lowest peak: -1.0723619858423845
# Processing file: cleaned_90mV 300Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-2.08068848 -2.02632904 -2.02299118 -2.03014374 -2.05493927 -2.05446243
#  -2.04409122 -2.03491211 -2.03205109 -2.04397202]
# Number of data points: 504
# Lowest value found: -9.06637668609619
# Normalized value of the lowest peak: 0.40662294183842285
# Processing file: cleaned_90mV 300Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-3.57748508 -3.47210407 -3.4506464  -3.42394352 -3.38579655 -3.33429813
#  -3.34049702 -3.29138279 -3.26515675 -3.22557926]
# Number of data points: 504
# Lowest value found: -3.57748508453369
# Normalized value of the lowest peak: -1.431217551231383
# Processing file: cleaned_90mV 40Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-0.30207634 -0.29969215 -0.29730797 -0.29921532 -0.29778481 -0.29730797
#  -0.29683113 -0.29873848 -0.29921532 -0.29873848]
# Number of data points: 202
# Lowest value found: -0.379323959350586
# Normalized value of the lowest peak: 0.6510239572667365
# Processing file: cleaned_90mV 40Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-0.76795101 -0.75936794 -0.75841427 -0.75650692 -0.75746059 -0.75698376
#  -0.75841427 -0.75698376 -0.75889111 -0.75746059]
# Number of data points: 202
# Lowest value found: -0.84662914276123
# Normalized value of the lowest peak: -0.006978191546539336
# Processing file: cleaned_90mV 40Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.09179115 -0.08893013 -0.0898838  -0.08940697 -0.09059906 -0.09179115
#  -0.09131432 -0.09083748 -0.0898838  -0.09036064]
# Number of data points: 202
# Lowest value found: -0.13279914855957
# Normalized value of the lowest peak: -0.005236104946231085
# Processing file: cleaned_90mV 40Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-1.01066113 -1.00255489 -0.99969387 -0.99826336 -1.00064754 -0.99778652
#  -0.9987402  -0.99969387 -1.00064754 -1.00112438]
# Number of data points: 202
# Lowest value found: -1.16563320159912
# Normalized value of the lowest peak: 0.004457715731949419
# Processing file: cleaned_90mV 40Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.15759468 -0.15521049 -0.15425682 -0.15187263 -0.15568733 -0.15330315
#  -0.15234947 -0.15425682 -0.15377998 -0.15377998]
# Number of data points: 202
# Lowest value found: -0.28681755065918
# Normalized value of the lowest peak: 0.021129757610719224
# Processing file: cleaned_90mV 40Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-0.35214424 -0.34451485 -0.34117699 -0.34070015 -0.34308434 -0.34022331
#  -0.34308434 -0.3426075  -0.34117699 -0.34022331]
# Number of data points: 202
# Lowest value found: -0.501871109008789
# Normalized value of the lowest peak: 0.49939475842376224
# Processing file: cleaned_90mV 40Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-1.47319317 -1.4812994  -1.48940563 -1.50275707 -1.51610851 -1.52373791
#  -1.53327465 -1.54853344 -1.56045437 -1.57142162]
# Number of data points: 202
# Lowest value found: -4.06099796295166
# Normalized value of the lowest peak: 0.007896067491218517
# Processing file: cleaned_90mV 40Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-0.19526482 -0.19001961 -0.19145012 -0.18954277 -0.18906593 -0.18811226
#  -0.18763542 -0.18954277 -0.19145012 -0.19049644]
# Number of data points: 202
# Lowest value found: -0.327348709106445
# Normalized value of the lowest peak: 0.08540865200669068
# Processing file: cleaned_90mV 60Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-1.69539928 -1.64771557 -1.62148952 -1.60146236 -1.5814352  -1.56522274
#  -1.54853344 -1.53565884 -1.51563168 -1.49989605]
# Number of data points: 504
# Lowest value found: -1.69539928436279
# Normalized value of the lowest peak: -0.8087966601053845
# Processing file: cleaned_90mV 60Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-1.65296078 -1.63197994 -1.62005901 -1.61290646 -1.6057539  -1.59860134
#  -1.59192562 -1.58191204 -1.57523632 -1.56569958]
# Number of data points: 504
# Lowest value found: -1.65296077728271
# Normalized value of the lowest peak: -0.40029764175414595
# Processing file: cleaned_90mV 60Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.67210674 -0.65827847 -0.65160275 -0.64731121 -0.63491344 -0.63109875
#  -0.62298775 -0.62012672 -0.61297417 -0.60677528]
# Number of data points: 504
# Lowest value found: -0.672106742858887
# Normalized value of the lowest peak: -0.30631205240885456
# Processing file: cleaned_90mV 60Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-2.09022522 -2.05446243 -2.04444885 -2.02775955 -2.01536179 -2.00105667
#  -1.99008942 -1.97769165 -1.96767807 -1.95098877]
# Number of data points: 504
# Lowest value found: -2.09022521972656
# Normalized value of the lowest peak: -0.5733015696207657
# Processing file: cleaned_90mV 60Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.45990944 -0.45371056 -0.44846535 -0.44369698 -0.43511391 -0.43702126
#  -0.42843819 -0.42796135 -0.42462349 -0.42033195]
# Number of data points: 504
# Lowest value found: -0.459909439086914
# Normalized value of the lowest peak: -0.15525519847869867
# Processing file: cleaned_90mV 60Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-1.22905254 -1.19996548 -1.1823225  -1.1694479  -1.15228176 -1.14417553
#  -1.12891674 -1.11794949 -1.10364437 -1.09267712]
# Number of data points: 504
# Lowest value found: -1.22905254364014
# Normalized value of the lowest peak: -0.5283768335978224
# Processing file: cleaned_90mV 60Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.65303326 -0.64063549 -0.63872814 -0.6382513  -0.63634396 -0.63443661
#  -0.63586712 -0.63205242 -0.63348293 -0.63443661]
# Number of data points: 504
# Lowest value found: -0.981574058532715
# Normalized value of the lowest peak: 1.4271681118833062
# Processing file: cleaned_90mV 60Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-1.22094631 -1.1899519  -1.17230892 -1.15561962 -1.14131451 -1.12748623
#  -1.11508846 -1.10078335 -1.08790874 -1.07408047]
# Number of data points: 504
# Lowest value found: -1.22094631195068
# Normalized value of the lowest peak: -0.611644299825029
# Processing file: cleaned_90mV 80Hz_µA_1.csv
# Data loaded from CSV (first 10 values): [-2.77257919 -2.68865585 -2.65289307 -2.61617661 -2.58756638 -2.55847931
#  -2.52653122 -2.49696732 -2.47360229 -2.44594574]
# Number of data points: 504
# Lowest value found: -2.77257919311523
# Normalized value of the lowest peak: -1.36596412658691
# Processing file: cleaned_90mV 80Hz_µA_2.csv
# Data loaded from CSV (first 10 values): [-2.00201035 -1.97435379 -1.9667244  -1.95289612 -1.94717407 -1.94192886
#  -1.93429947 -1.92237854 -1.91379547 -1.90139771]
# Number of data points: 504
# Lowest value found: -2.00201034545898
# Normalized value of the lowest peak: -0.4491086641947384
# Processing file: cleaned_90mV 80Hz_µA_3.csv
# Data loaded from CSV (first 10 values): [-0.82087994 -0.80085278 -0.79703808 -0.78511715 -0.77891827 -0.77224255
#  -0.76604366 -0.75412273 -0.7498312  -0.74172497]
# Number of data points: 504
# Lowest value found: -0.820879936218262
# Normalized value of the lowest peak: -0.36062072118123406
# Processing file: cleaned_90mV 80Hz_µA_4.csv
# Data loaded from CSV (first 10 values): [-2.70200729 -2.66195297 -2.6404953  -2.62189865 -2.59662628 -2.58756638
#  -2.57040024 -2.5494194  -2.53225327 -2.52128601]
# Number of data points: 504
# Lowest value found: -2.70200729370117
# Normalized value of the lowest peak: -0.7986620267232241
# Processing file: cleaned_90mV 80Hz_µA_5.csv
# Data loaded from CSV (first 10 values): [-0.59437752 -0.58531761 -0.57816505 -0.57530403 -0.56576729 -0.56433678
#  -0.56052208 -0.55384636 -0.55241585 -0.54621696]
# Number of data points: 504
# Lowest value found: -0.594377517700195
# Normalized value of the lowest peak: -0.18684943517049118
# Processing file: cleaned_90mV 80Hz_µA_6.csv
# Data loaded from CSV (first 10 values): [-1.40405178 -1.3735342  -1.35255337 -1.33872509 -1.32489681 -1.30916119
#  -1.30010128 -1.28245831 -1.27292156 -1.25718594]
# Number of data points: 504
# Lowest value found: -1.40405178070068
# Normalized value of the lowest peak: -0.5613496303558315
# Processing file: cleaned_90mV 80Hz_µA_7.csv
# Data loaded from CSV (first 10 values): [-0.74792385 -0.74029446 -0.72694302 -0.73123455 -0.72503567 -0.72980404
#  -0.72980404 -0.7293272  -0.73123455 -0.72694302]
# Number of data points: 504
# Lowest value found: -1.24860286712646
# Normalized value of the lowest peak: 1.2588546906503533
# Processing file: cleaned_90mV 80Hz_µA_8.csv
# Data loaded from CSV (first 10 values): [-1.49465084 -1.46031857 -1.43933773 -1.41597271 -1.40023708 -1.38640881
#  -1.36876583 -1.35112286 -1.33491039 -1.32251263]
# Number of data points: 504
# Lowest value found: -1.49465084075928
# Normalized value of the lowest peak: -0.7338592529296901
#
# Normalized values of the lowest peaks:
#                               Normalized Value
# Filename
# cleaned_100mV 100Hz_µA_1.csv         -1.840894
# cleaned_100mV 100Hz_µA_2.csv         -0.621797
# cleaned_100mV 100Hz_µA_3.csv         -0.478370
# cleaned_100mV 100Hz_µA_4.csv         -0.823986
# cleaned_100mV 100Hz_µA_5.csv         -0.261432
# ...                                        ...
# cleaned_90mV 80Hz_µA_4.csv           -0.798662
# cleaned_90mV 80Hz_µA_5.csv           -0.186849
# cleaned_90mV 80Hz_µA_6.csv           -0.561350
# cleaned_90mV 80Hz_µA_7.csv            1.258855
# cleaned_90mV 80Hz_µA_8.csv           -0.733859
#
# [553 rows x 1 columns]
